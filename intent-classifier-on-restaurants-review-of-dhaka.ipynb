# %%
# !pip install rasa_core
# !pip install rasa_nlu[spacy]
# !python -m spacy download en_core_web_lg
# !python -m spacy link en_core_web_lg en


# !pip install -U scikit-learn scipy sklearn-crfsuite
# !pip install rasa_nlu
# !pip install rasa_nlu[spacy]
# Out:
# Collecting rasa_core
#   Downloading https://files.pythonhosted.org/packages/cd/7b/58a6a997023a8b1f6a0e292d08fd88b4d39ec325e103c6cebd1eb38f6545/rasa_core-0.14.5-py3-none-any.whl (212kB)
#     100% |████████████████████████████████| 215kB 1.9MB/s
# Collecting mattermostwrapper~=2.0 (from rasa_core)
#   Downloading https://files.pythonhosted.org/packages/d7/fd/f1ce046ddaeffa5073f87d7800c27ad2c8e543e924a8418675c64aea6a14/mattermostwrapper-2.2.tar.gz
# Collecting rasa-core-sdk~=0.14 (from rasa_core)
#   Downloading https://files.pythonhosted.org/packages/bc/5b/343937a872b497079803878e5a6f75deb4aeb00504d32601a0ffd37b90f4/rasa_core_sdk-0.14.0-py2.py3-none-any.whl
# Collecting python-socketio~=3.0 (from rasa_core)
#   Downloading https://files.pythonhosted.org/packages/b5/db/dc823aa0b3397e52ebe8bba62ee39d6b9a088377809bc230d3ad2e5d2448/python_socketio-3.1.2-py2.py3-none-any.whl (43kB)
#     100% |████████████████████████████████| 51kB 5.7MB/s
# Collecting rasa-nlu~=0.15 (from rasa_core)
#   Downloading https://files.pythonhosted.org/packages/19/c4/c6146c445a17b6ce414d773f93c941c44ca16720609000ae3d01409f9dfb/rasa_nlu-0.15.1-py3-none-any.whl (147kB)
#     100% |████████████████████████████████| 153kB 4.1MB/s
# Requirement already satisfied: pymongo~=3.7 in /opt/conda/lib/python3.6/site-packages (from rasa_core) (3.7.2)
# Collecting pika~=0.12.0 (from rasa_core)
#   Downloading https://files.pythonhosted.org/packages/bf/48/72de47f63ba353bacd74b76bb65bc63620b0706d8b0471798087cd5a4916/pika-0.12.0-py2.py3-none-any.whl (108kB)
#     100% |████████████████████████████████| 112kB 3.8MB/s
# Collecting apscheduler~=3.0 (from rasa_core)
#   Downloading https://files.pythonhosted.org/packages/f3/34/9ef20ed473c4fd2c3df54ef77a27ae3fc7500b16b192add4720cab8b2c09/APScheduler-3.6.3-py2.py3-none-any.whl (58kB)
#     100% |████████████████████████████████| 61kB 4.7MB/s
# Collecting networkx~=2.2 (from rasa_core)
#   Downloading https://files.pythonhosted.org/packages/9b/cd/dc52755d30ba41c60243235460961fc28022e5b6731f16c268667625baea/networkx-2.5-py3-none-any.whl (1.6MB)
#     100% |████████████████████████████████| 1.6MB 3.8MB/s
# Collecting packaging~=18.0 (from rasa_core)
#   Downloading https://files.pythonhosted.org/packages/89/d1/92e6df2e503a69df9faab187c684585f0136662c12bb1f36901d426f3fab/packaging-18.0-py2.py3-none-any.whl
# Requirement already satisfied: scikit-learn~=0.20.0 in /opt/conda/lib/python3.6/site-packages (from rasa_core) (0.20.3)
# Requirement already satisfied: pydot~=1.4 in /opt/conda/lib/python3.6/site-packages (from rasa_core) (1.4.1)
# Requirement already satisfied: tensorflow~=1.13.0 in /opt/conda/lib/python3.6/site-packages (from rasa_core) (1.13.1)
# Requirement already satisfied: tqdm~=4.0 in /opt/conda/lib/python3.6/site-packages (from rasa_core) (4.31.1)
# Collecting webexteamssdk~=1.0 (from rasa_core)
#   Downloading https://files.pythonhosted.org/packages/4d/27/20edad1a463bd709e90ccc6be12cd5ce5db7ebeda98084143902c226adda/webexteamssdk-1.6-py3-none-any.whl (113kB)
#     100% |████████████████████████████████| 122kB 5.6MB/s
# Collecting fbmessenger~=5.0 (from rasa_core)
#   Downloading https://files.pythonhosted.org/packages/51/9d/9a426160e00c3c9d839314685fcec1f60ad04888be4228399dadb37c3226/fbmessenger-5.6.0-py2.py3-none-any.whl
# Collecting flask-jwt-simple~=0.0.3 (from rasa_core)
#   Downloading https://files.pythonhosted.org/packages/e7/5f/432fde78e3a7dda20576396ebf561770a83104dc4b74a1ee84e71574ec0a/Flask-JWT-Simple-0.0.3.tar.gz
# Collecting scipy~=1.2 (from rasa_core)
#   Downloading https://files.pythonhosted.org/packages/2b/a8/f4c66eb529bb252d50e83dbf2909c6502e2f857550f22571ed8556f62d95/scipy-1.5.2-cp36-cp36m-manylinux1_x86_64.whl (25.9MB)
#     100% |████████████████████████████████| 25.9MB 1.4MB/s
# Collecting python-dateutil~=2.7 (from rasa_core)
#   Downloading https://files.pythonhosted.org/packages/d4/70/d60450c3dd48ef87586924207ae8907090de0b306af2bce5d134d78615cb/python_dateutil-2.8.1-py2.py3-none-any.whl (227kB)
#     100% |████████████████████████████████| 235kB 21.2MB/s
# Collecting fakeredis~=0.10.0 (from rasa_core)
#   Downloading https://files.pythonhosted.org/packages/64/bd/2756ddf350c4bb308e3255f9dcd6610f8b01344947bf74d5d166dc66b0a2/fakeredis-0.10.3-py2.py3-none-any.whl
# Requirement already satisfied: gevent~=1.3 in /opt/conda/lib/python3.6/site-packages (from rasa_core) (1.3.0)
# Collecting redis~=2.0 (from rasa_core)
#   Downloading https://files.pythonhosted.org/packages/3b/f6/7a76333cf0b9251ecf49efff635015171843d9b977e4ffcf59f9c4428052/redis-2.10.6-py2.py3-none-any.whl (64kB)
#     100% |████████████████████████████████| 71kB 25.9MB/s
# Collecting rocketchat-API~=0.6.0 (from rasa_core)
#   Downloading https://files.pythonhosted.org/packages/8e/e6/69e5d75ad687635c56a27a8529c471cf1a8593e071784c4d2727382cd5db/rocketchat_API-0.6.36-py3-none-any.whl
# Collecting questionary>=1.0.1 (from rasa_core)
#   Downloading https://files.pythonhosted.org/packages/05/7d/61b7d0da15bb50e7239c870771320026447b7e2d9490ee96f49dddd3ef0d/questionary-1.5.2-py3-none-any.whl
# Collecting python-telegram-bot~=11.0 (from rasa_core)
#   Downloading https://files.pythonhosted.org/packages/84/6c/47932a4041ee76650ad1f45a80e1422077e1e99c08a4d7a61cfbe5393d41/python_telegram_bot-11.1.0-py2.py3-none-any.whl (326kB)
#     100% |████████████████████████████████| 327kB 21.3MB/s
# Collecting coloredlogs~=10.0 (from rasa_core)
#   Downloading https://files.pythonhosted.org/packages/08/0f/7877fc42fff0b9d70b6442df62d53b3868d3a6ad1b876bdb54335b30ff23/coloredlogs-10.0-py2.py3-none-any.whl (47kB)
#     100% |████████████████████████████████| 51kB 21.3MB/s
# Collecting terminaltables~=3.1 (from rasa_core)
#   Downloading https://files.pythonhosted.org/packages/9b/c4/4a21174f32f8a7e1104798c445dacdc1d4df86f2f26722767034e4de4bff/terminaltables-3.1.0.tar.gz
# Collecting twilio~=6.0 (from rasa_core)
#   Downloading https://files.pythonhosted.org/packages/20/3a/5c17dc8fd4feee1853dc394bc84b109350b64cf95c7d4ad3e484c916cc04/twilio-6.45.1.tar.gz (438kB)
#     100% |████████████████████████████████| 440kB 19.6MB/s
# Collecting pytz~=2018.9 (from rasa_core)
#   Downloading https://files.pythonhosted.org/packages/61/28/1d3920e4d1d50b19bc5d24398a7cd85cc7b9a75a490570d5a30c57622d34/pytz-2018.9-py2.py3-none-any.whl (510kB)
#     100% |████████████████████████████████| 512kB 18.4MB/s
# Requirement already satisfied: jsonschema~=2.6 in /opt/conda/lib/python3.6/site-packages (from rasa_core) (2.6.0)
# Requirement already satisfied: flask-cors~=3.0 in /opt/conda/lib/python3.6/site-packages (from rasa_core) (3.0.4)
# Requirement already satisfied: numpy~=1.16 in /opt/conda/lib/python3.6/site-packages (from rasa_core) (1.16.2)
# Collecting colorclass~=2.2 (from rasa_core)
#   Downloading https://files.pythonhosted.org/packages/37/ea/ae8dbb956939d4392e6a7fdef87fda273854da1128edae016c4104240be8/colorclass-2.2.0.tar.gz
# Collecting slackclient~=1.0 (from rasa_core)
#   Downloading https://files.pythonhosted.org/packages/7c/2f/9b6db4c7686be3dc6b4244eaef4f37226a2ccca1a796516d4adcdfeefe56/slackclient-1.3.2.tar.gz
# Requirement already satisfied: flask~=1.0 in /opt/conda/lib/python3.6/site-packages (from rasa_core) (1.0.2)
# Collecting jsonpickle~=1.0 (from rasa_core)
#   Downloading https://files.pythonhosted.org/packages/af/ca/4fee219cc4113a5635e348ad951cf8a2e47fed2e3342312493f5b73d0007/jsonpickle-1.4.1-py2.py3-none-any.whl
# Requirement already satisfied: typing~=3.0 in /opt/conda/lib/python3.6/site-packages (from rasa_core) (3.6.4)
# Collecting ruamel.yaml~=0.15.0 (from rasa_core)
#   Downloading https://files.pythonhosted.org/packages/e7/9f/83bb34eaf84032b0b54fcc4a6aff1858572d279d65a301c7ae875f523df5/ruamel.yaml-0.15.100-cp36-cp36m-manylinux1_x86_64.whl (656kB)
#     100% |████████████████████████████████| 665kB 19.5MB/s
# Requirement already satisfied: requests~=2.20 in /opt/conda/lib/python3.6/site-packages (from rasa_core) (2.21.0)
# Collecting colorhash~=1.0 (from rasa_core)
#   Downloading https://files.pythonhosted.org/packages/0e/e1/50dbc513aa74e99eca4c47f2a8206711f0bec436fdddd95eebaf7eaaa1aa/colorhash-1.0.2-py2.py3-none-any.whl
# Collecting pykwalify~=1.7.0 (from rasa_core)
#   Downloading https://files.pythonhosted.org/packages/36/9f/612de8ca540bd24d604f544248c4c46e9db76f6ea5eb75fb4244da6ebbf0/pykwalify-1.7.0-py2.py3-none-any.whl (40kB)
#     100% |████████████████████████████████| 40kB 16.9MB/s
# Requirement already satisfied: six~=1.11 in /opt/conda/lib/python3.6/site-packages (from rasa-core-sdk~=0.14->rasa_core) (1.12.0)
# Requirement already satisfied: future~=0.16 in /opt/conda/lib/python3.6/site-packages (from rasa-core-sdk~=0.14->rasa_core) (0.17.1)
# Collecting ConfigArgParse~=0.13.0 (from rasa-core-sdk~=0.14->rasa_core)
#   Downloading https://files.pythonhosted.org/packages/77/61/ae928ce6ab85d4479ea198488cf5ffa371bd4ece2030c0ee85ff668deac5/ConfigArgParse-0.13.0.tar.gz
# Collecting python-engineio>=3.2.0 (from python-socketio~=3.0->rasa_core)
#   Downloading https://files.pythonhosted.org/packages/4a/b0/602e549c6d735eb487f186b35e0b82e61c89459f57d1c24d5c7be6f56d05/python_engineio-3.13.2-py2.py3-none-any.whl (50kB)
#     100% |████████████████████████████████| 51kB 18.5MB/s
# Collecting klein~=17.10 (from rasa-nlu~=0.15->rasa_core)
#   Downloading https://files.pythonhosted.org/packages/8a/6b/adc97a7bb3fb781fdd9e49177ad873c1479f87b9745271cbeda81cbb9cc8/klein-17.10.0-py2.py3-none-any.whl
# Collecting cloudpickle~=0.6.1 (from rasa-nlu~=0.15->rasa_core)
#   Downloading https://files.pythonhosted.org/packages/fc/87/7b7ef3038b4783911e3fdecb5c566e3a817ce3e890e164fc174c088edb1e/cloudpickle-0.6.1-py2.py3-none-any.whl
# Collecting simplejson~=3.13 (from rasa-nlu~=0.15->rasa_core)
#   Downloading https://files.pythonhosted.org/packages/73/96/1e6b19045375890068d7342cbe280dd64ae73fd90b9735b5efb8d1e044a1/simplejson-3.17.2-cp36-cp36m-manylinux2010_x86_64.whl (127kB)
#     100% |████████████████████████████████| 133kB 29.7MB/s
# Requirement already satisfied: boto3~=1.9 in /opt/conda/lib/python3.6/site-packages (from rasa-nlu~=0.15->rasa_core) (1.9.130)
# Collecting matplotlib~=2.2 (from rasa-nlu~=0.15->rasa_core)
#   Downloading https://files.pythonhosted.org/packages/49/cc/94dd12083678ffbfee7cf5ac8bf341b0e6dac64c422851db094e532d1524/matplotlib-2.2.5-cp36-cp36m-manylinux1_x86_64.whl (12.8MB)
#     100% |████████████████████████████████| 12.8MB 3.6MB/s
# Requirement already satisfied: setuptools>=0.7 in /opt/conda/lib/python3.6/site-packages (from apscheduler~=3.0->rasa_core) (39.1.0)
# Requirement already satisfied: tzlocal>=1.2 in /opt/conda/lib/python3.6/site-packages (from apscheduler~=3.0->rasa_core) (1.5.1)
# Requirement already satisfied: decorator>=4.3.0 in /opt/conda/lib/python3.6/site-packages (from networkx~=2.2->rasa_core) (4.3.0)
# Requirement already satisfied: pyparsing>=2.0.2 in /opt/conda/lib/python3.6/site-packages (from packaging~=18.0->rasa_core) (2.2.0)
# Requirement already satisfied: astor>=0.6.0 in /opt/conda/lib/python3.6/site-packages (from tensorflow~=1.13.0->rasa_core) (0.7.1)
# Requirement already satisfied: wheel>=0.26 in /opt/conda/lib/python3.6/site-packages (from tensorflow~=1.13.0->rasa_core) (0.31.1)
# Requirement already satisfied: gast>=0.2.0 in /opt/conda/lib/python3.6/site-packages (from tensorflow~=1.13.0->rasa_core) (0.2.2)
# Requirement already satisfied: keras-applications>=1.0.6 in /opt/conda/lib/python3.6/site-packages (from tensorflow~=1.13.0->rasa_core) (1.0.7)
# Requirement already satisfied: tensorflow-estimator<1.14.0rc0,>=1.13.0 in /opt/conda/lib/python3.6/site-packages (from tensorflow~=1.13.0->rasa_core) (1.13.0)
# Requirement already satisfied: protobuf>=3.6.1 in /opt/conda/lib/python3.6/site-packages (from tensorflow~=1.13.0->rasa_core) (3.7.1)
# Requirement already satisfied: tensorboard<1.14.0,>=1.13.0 in /opt/conda/lib/python3.6/site-packages (from tensorflow~=1.13.0->rasa_core) (1.13.1)
# Requirement already satisfied: grpcio>=1.8.6 in /opt/conda/lib/python3.6/site-packages (from tensorflow~=1.13.0->rasa_core) (1.19.0)
# Requirement already satisfied: absl-py>=0.1.6 in /opt/conda/lib/python3.6/site-packages (from tensorflow~=1.13.0->rasa_core) (0.7.1)
# Requirement already satisfied: keras-preprocessing>=1.0.5 in /opt/conda/lib/python3.6/site-packages (from tensorflow~=1.13.0->rasa_core) (1.0.9)
# Requirement already satisfied: termcolor>=1.1.0 in /opt/conda/lib/python3.6/site-packages (from tensorflow~=1.13.0->rasa_core) (1.1.0)
# Collecting requests-toolbelt (from webexteamssdk~=1.0->rasa_core)
#   Downloading https://files.pythonhosted.org/packages/60/ef/7681134338fc097acef8d9b2f8abe0458e4d87559c689a8c306d0957ece5/requests_toolbelt-0.9.1-py2.py3-none-any.whl (54kB)
#     100% |████████████████████████████████| 61kB 19.2MB/s
# Collecting PyJWT (from webexteamssdk~=1.0->rasa_core)
#   Downloading https://files.pythonhosted.org/packages/87/8b/6a9f14b5f781697e51259d81657e6048fd31a113229cf346880bb7545565/PyJWT-1.7.1-py2.py3-none-any.whl
# Requirement already satisfied: greenlet>=0.4.13 in /opt/conda/lib/python3.6/site-packages (from gevent~=1.3->rasa_core) (0.4.13)
# Collecting prompt-toolkit<4.0,>=2.0 (from questionary>=1.0.1->rasa_core)
#   Downloading https://files.pythonhosted.org/packages/2b/c1/53ac685833200eb77ef485c2220dac5bfc255418e660790a9eb5cf3abf25/prompt_toolkit-3.0.7-py3-none-any.whl (355kB)
#     100% |████████████████████████████████| 358kB 29.7MB/s
# Requirement already satisfied: cryptography in /opt/conda/lib/python3.6/site-packages (from python-telegram-bot~=11.0->rasa_core) (2.2.2)
# Requirement already satisfied: certifi in /opt/conda/lib/python3.6/site-packages (from python-telegram-bot~=11.0->rasa_core) (2019.3.9)
# Collecting humanfriendly>=4.7 (from coloredlogs~=10.0->rasa_core)
#   Downloading https://files.pythonhosted.org/packages/8e/2d/2f1b0a780b8c948c06c74c8c80e68ac354da52397ba432a1c5ac1923c3af/humanfriendly-8.2-py2.py3-none-any.whl (86kB)
#     100% |████████████████████████████████| 92kB 27.6MB/s
# Collecting websocket-client<0.55.0,>=0.35 (from slackclient~=1.0->rasa_core)
#   Downloading https://files.pythonhosted.org/packages/26/2d/f749a5c82f6192d77ed061a38e02001afcba55fe8477336d26a950ab17ce/websocket_client-0.54.0-py2.py3-none-any.whl (200kB)
#     100% |████████████████████████████████| 204kB 34.4MB/s
# Requirement already satisfied: Werkzeug>=0.14 in /opt/conda/lib/python3.6/site-packages (from flask~=1.0->rasa_core) (0.14.1)
# Requirement already satisfied: itsdangerous>=0.24 in /opt/conda/lib/python3.6/site-packages (from flask~=1.0->rasa_core) (0.24)
# Requirement already satisfied: click>=5.1 in /opt/conda/lib/python3.6/site-packages (from flask~=1.0->rasa_core) (7.0)
# Requirement already satisfied: Jinja2>=2.10 in /opt/conda/lib/python3.6/site-packages (from flask~=1.0->rasa_core) (2.10)
# Collecting importlib-metadata (from jsonpickle~=1.0->rasa_core)
#   Downloading https://files.pythonhosted.org/packages/8e/58/cdea07eb51fc2b906db0968a94700866fc46249bdc75cac23f9d13168929/importlib_metadata-1.7.0-py2.py3-none-any.whl
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /opt/conda/lib/python3.6/site-packages (from requests~=2.20->rasa_core) (3.0.4)
# Requirement already satisfied: idna<2.9,>=2.5 in /opt/conda/lib/python3.6/site-packages (from requests~=2.20->rasa_core) (2.6)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in /opt/conda/lib/python3.6/site-packages (from requests~=2.20->rasa_core) (1.22)
# Requirement already satisfied: docopt>=0.6.2 in /opt/conda/lib/python3.6/site-packages (from pykwalify~=1.7.0->rasa_core) (0.6.2)
# Requirement already satisfied: PyYAML>=3.11 in /opt/conda/lib/python3.6/site-packages (from pykwalify~=1.7.0->rasa_core) (3.12)
# Collecting Twisted>=15.5 (from klein~=17.10->rasa-nlu~=0.15->rasa_core)
#   Downloading https://files.pythonhosted.org/packages/b7/04/1a664c9e5ec0224a1c1a154ddecaa4dc7b8967521bba225efcc41a03d5f3/Twisted-20.3.0-cp36-cp36m-manylinux1_x86_64.whl (3.1MB)
#     100% |████████████████████████████████| 3.1MB 3.2MB/s
# Collecting incremental (from klein~=17.10->rasa-nlu~=0.15->rasa_core)
#   Downloading https://files.pythonhosted.org/packages/f5/1d/c98a587dc06e107115cf4a58b49de20b19222c83d75335a192052af4c4b7/incremental-17.5.0-py2.py3-none-any.whl
# Requirement already satisfied: botocore<1.13.0,>=1.12.130 in /opt/conda/lib/python3.6/site-packages (from boto3~=1.9->rasa-nlu~=0.15->rasa_core) (1.12.130)
# Requirement already satisfied: jmespath<1.0.0,>=0.7.1 in /opt/conda/lib/python3.6/site-packages (from boto3~=1.9->rasa-nlu~=0.15->rasa_core) (0.9.4)
# Requirement already satisfied: s3transfer<0.3.0,>=0.2.0 in /opt/conda/lib/python3.6/site-packages (from boto3~=1.9->rasa-nlu~=0.15->rasa_core) (0.2.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/conda/lib/python3.6/site-packages (from matplotlib~=2.2->rasa-nlu~=0.15->rasa_core) (1.0.1)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.6/site-packages (from matplotlib~=2.2->rasa-nlu~=0.15->rasa_core) (0.10.0)
# Requirement already satisfied: h5py in /opt/conda/lib/python3.6/site-packages (from keras-applications>=1.0.6->tensorflow~=1.13.0->rasa_core) (2.9.0)
# Requirement already satisfied: mock>=2.0.0 in /opt/conda/lib/python3.6/site-packages (from tensorflow-estimator<1.14.0rc0,>=1.13.0->tensorflow~=1.13.0->rasa_core) (2.0.0)
# Requirement already satisfied: markdown>=2.6.8 in /opt/conda/lib/python3.6/site-packages (from tensorboard<1.14.0,>=1.13.0->tensorflow~=1.13.0->rasa_core) (3.1)
# Requirement already satisfied: wcwidth in /opt/conda/lib/python3.6/site-packages (from prompt-toolkit<4.0,>=2.0->questionary>=1.0.1->rasa_core) (0.1.7)
# Requirement already satisfied: asn1crypto>=0.21.0 in /opt/conda/lib/python3.6/site-packages (from cryptography->python-telegram-bot~=11.0->rasa_core) (0.24.0)
# Requirement already satisfied: cffi>=1.7 in /opt/conda/lib/python3.6/site-packages (from cryptography->python-telegram-bot~=11.0->rasa_core) (1.11.5)
# Requirement already satisfied: MarkupSafe>=0.23 in /opt/conda/lib/python3.6/site-packages (from Jinja2>=2.10->flask~=1.0->rasa_core) (1.0)
# Collecting zipp>=0.5 (from importlib-metadata->jsonpickle~=1.0->rasa_core)
#   Downloading https://files.pythonhosted.org/packages/b2/34/bfcb43cc0ba81f527bc4f40ef41ba2ff4080e047acb0586b56b3d017ace4/zipp-3.1.0-py3-none-any.whl
# Collecting hyperlink>=17.1.1 (from Twisted>=15.5->klein~=17.10->rasa-nlu~=0.15->rasa_core)
#   Downloading https://files.pythonhosted.org/packages/88/a5/74f77547e9b175eb894d4fec5c76b0c8176c045e5bf3ac6a4d4d3feab4bb/hyperlink-20.0.1-py2.py3-none-any.whl (48kB)
#     100% |████████████████████████████████| 51kB 20.0MB/s
# Collecting attrs>=19.2.0 (from Twisted>=15.5->klein~=17.10->rasa-nlu~=0.15->rasa_core)
#   Downloading https://files.pythonhosted.org/packages/14/df/479736ae1ef59842f512548bacefad1abed705e400212acba43f9b0fa556/attrs-20.2.0-py2.py3-none-any.whl (48kB)
#     100% |████████████████████████████████| 51kB 19.6MB/s
# Collecting zope.interface>=4.4.2 (from Twisted>=15.5->klein~=17.10->rasa-nlu~=0.15->rasa_core)
#   Downloading https://files.pythonhosted.org/packages/57/33/565274c28a11af60b7cfc0519d46bde4125fcd7d32ebc0a81b480d0e8da6/zope.interface-5.1.0-cp36-cp36m-manylinux2010_x86_64.whl (234kB)
#     100% |████████████████████████████████| 235kB 19.1MB/s
# Collecting Automat>=0.3.0 (from Twisted>=15.5->klein~=17.10->rasa-nlu~=0.15->rasa_core)
#   Downloading https://files.pythonhosted.org/packages/dd/83/5f6f3c1a562674d65efc320257bdc0873ec53147835aeef7762fe7585273/Automat-20.2.0-py2.py3-none-any.whl
# Collecting PyHamcrest!=1.10.0,>=1.9.0 (from Twisted>=15.5->klein~=17.10->rasa-nlu~=0.15->rasa_core)
#   Downloading https://files.pythonhosted.org/packages/40/16/e54cc65891f01cb62893540f44ffd3e8dab0a22443e1b438f1a9f5574bee/PyHamcrest-2.0.2-py3-none-any.whl (52kB)
#     100% |████████████████████████████████| 61kB 19.0MB/s
# Collecting constantly>=15.1 (from Twisted>=15.5->klein~=17.10->rasa-nlu~=0.15->rasa_core)
#   Downloading https://files.pythonhosted.org/packages/b9/65/48c1909d0c0aeae6c10213340ce682db01b48ea900a7d9fce7a7910ff318/constantly-15.1.0-py2.py3-none-any.whl
# Requirement already satisfied: docutils>=0.10 in /opt/conda/lib/python3.6/site-packages (from botocore<1.13.0,>=1.12.130->boto3~=1.9->rasa-nlu~=0.15->rasa_core) (0.14)
# Requirement already satisfied: pbr>=0.11 in /opt/conda/lib/python3.6/site-packages (from mock>=2.0.0->tensorflow-estimator<1.14.0rc0,>=1.13.0->tensorflow~=1.13.0->rasa_core) (5.1.3)
# Requirement already satisfied: pycparser in /opt/conda/lib/python3.6/site-packages (from cffi>=1.7->cryptography->python-telegram-bot~=11.0->rasa_core) (2.18)
# Building wheels for collected packages: mattermostwrapper, flask-jwt-simple, terminaltables, twilio, colorclass, slackclient, ConfigArgParse
# done
#   Stored in directory: /root/.cache/pip/wheels/c5/47/19/47188b3036316651250c4f7df23d59a3b524c82921bfb6daa3
# done
#   Stored in directory: /root/.cache/pip/wheels/5d/86/c2/49573c0ce194f3073438e56dad49c462fe9c9a69a4fbe7b3fc
# done
#   Stored in directory: /root/.cache/pip/wheels/30/6b/50/6c75775b681fb36cdfac7f19799888ef9d8813aff9e379663e
# done
#   Stored in directory: /root/.cache/pip/wheels/b7/2c/e0/eca1ecc36d8ed397cea02238aab8ed3b8fdd861fc94a55dc53
# done
#   Stored in directory: /root/.cache/pip/wheels/d1/86/9d/16127127306a92d7fd30267890a5634026c045391979c4c317
# done
#   Stored in directory: /root/.cache/pip/wheels/3b/d4/92/3458f0e1a3e1a9c8935d3b2db89a75d74d8d45601fedec752f
# done
#   Stored in directory: /root/.cache/pip/wheels/76/11/eb/12113becd46c0e8a70b8a63f9405e46a1f61d4aaa8532d676b
# Successfully built mattermostwrapper flask-jwt-simple terminaltables twilio colorclass slackclient ConfigArgParse
# sacred 0.7.4 has requirement jsonpickle<1.0,>=0.7.2, but you'll have jsonpickle 1.4.1 which is incompatible.
# pytest-cov 2.6.1 has requirement pytest>=3.6, but you'll have pytest 3.5.1 which is incompatible.
# lime 0.1.1.33 has requirement matplotlib==2.1.0, but you'll have matplotlib 2.2.5 which is incompatible.
# kmodes 0.10.0 has requirement scikit-learn<0.20.0,>=0.19.0, but you'll have scikit-learn 0.20.3 which is incompatible.
# kmeans-smote 0.1.2 has requirement imbalanced-learn<0.5,>=0.4.0, but you'll have imbalanced-learn 0.5.0.dev0 which is incompatible.
# kmeans-smote 0.1.2 has requirement numpy<1.16,>=1.13, but you'll have numpy 1.16.2 which is incompatible.
# jupyter-console 5.2.0 has requirement prompt_toolkit<2.0.0,>=1.0.0, but you'll have prompt-toolkit 3.0.7 which is incompatible.
# ipython 6.4.0 has requirement prompt-toolkit<2.0.0,>=1.0.15, but you'll have prompt-toolkit 3.0.7 which is incompatible.
# Installing collected packages: mattermostwrapper, humanfriendly, coloredlogs, ConfigArgParse, rasa-core-sdk, python-engineio, python-socketio, hyperlink, incremental, attrs, zope.interface, Automat, PyHamcrest, constantly, Twisted, klein, ruamel.yaml, packaging, cloudpickle, simplejson, pytz, python-dateutil, matplotlib, rasa-nlu, pika, apscheduler, networkx, requests-toolbelt, PyJWT, webexteamssdk, fbmessenger, flask-jwt-simple, scipy, redis, fakeredis, rocketchat-API, prompt-toolkit, questionary, python-telegram-bot, terminaltables, twilio, colorclass, websocket-client, slackclient, zipp, importlib-metadata, jsonpickle, colorhash, pykwalify, rasa-core
#   Found existing installation: ConfigArgParse 0.14.0
#     Uninstalling ConfigArgParse-0.14.0:
#       Successfully uninstalled ConfigArgParse-0.14.0
#   Found existing installation: attrs 18.1.0
#     Uninstalling attrs-18.1.0:
#       Successfully uninstalled attrs-18.1.0
#   Found existing installation: packaging 17.1
#     Uninstalling packaging-17.1:
#       Successfully uninstalled packaging-17.1
#   Found existing installation: cloudpickle 0.5.3
#     Uninstalling cloudpickle-0.5.3:
#       Successfully uninstalled cloudpickle-0.5.3
#   Found existing installation: pytz 2018.4
#     Uninstalling pytz-2018.4:
#       Successfully uninstalled pytz-2018.4
#   Found existing installation: python-dateutil 2.6.0
#     Uninstalling python-dateutil-2.6.0:
#       Successfully uninstalled python-dateutil-2.6.0
#   Found existing installation: matplotlib 3.0.3
#     Uninstalling matplotlib-3.0.3:
#       Successfully uninstalled matplotlib-3.0.3
#   Found existing installation: networkx 2.1
#     Uninstalling networkx-2.1:
#       Successfully uninstalled networkx-2.1
#   Found existing installation: scipy 1.1.0
#     Uninstalling scipy-1.1.0:
#       Successfully uninstalled scipy-1.1.0
#   Found existing installation: redis 3.2.1
#     Uninstalling redis-3.2.1:
#       Successfully uninstalled redis-3.2.1
#   Found existing installation: prompt-toolkit 1.0.15
#     Uninstalling prompt-toolkit-1.0.15:
#       Successfully uninstalled prompt-toolkit-1.0.15
#   Found existing installation: websocket-client 0.56.0
#     Uninstalling websocket-client-0.56.0:
#       Successfully uninstalled websocket-client-0.56.0
#   Found existing installation: jsonpickle 0.9.6
#     Uninstalling jsonpickle-0.9.6:
#       Successfully uninstalled jsonpickle-0.9.6
# Successfully installed Automat-20.2.0 ConfigArgParse-0.13.0 PyHamcrest-2.0.2 PyJWT-1.7.1 Twisted-20.3.0 apscheduler-3.6.3 attrs-20.2.0 cloudpickle-0.6.1 colorclass-2.2.0 coloredlogs-10.0 colorhash-1.0.2 constantly-15.1.0 fakeredis-0.10.3 fbmessenger-5.6.0 flask-jwt-simple-0.0.3 humanfriendly-8.2 hyperlink-20.0.1 importlib-metadata-1.7.0 incremental-17.5.0 jsonpickle-1.4.1 klein-17.10.0 matplotlib-2.2.5 mattermostwrapper-2.2 networkx-2.5 packaging-18.0 pika-0.12.0 prompt-toolkit-3.0.7 pykwalify-1.7.0 python-dateutil-2.8.1 python-engineio-3.13.2 python-socketio-3.1.2 python-telegram-bot-11.1.0 pytz-2018.9 questionary-1.5.2 rasa-core-0.14.5 rasa-core-sdk-0.14.0 rasa-nlu-0.15.1 redis-2.10.6 requests-toolbelt-0.9.1 rocketchat-API-0.6.36 ruamel.yaml-0.15.100 scipy-1.5.2 simplejson-3.17.2 slackclient-1.3.2 terminaltables-3.1.0 twilio-6.45.1 webexteamssdk-1.6 websocket-client-0.54.0 zipp-3.1.0 zope.interface-5.1.0
# You are using pip version 19.0.3, however version 20.2.2 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.
# Requirement already satisfied: rasa_nlu[spacy] in /opt/conda/lib/python3.6/site-packages (0.15.1)
# Requirement already satisfied: typing~=3.6 in /opt/conda/lib/python3.6/site-packages (from rasa_nlu[spacy]) (3.6.4)
# Requirement already satisfied: requests~=2.20 in /opt/conda/lib/python3.6/site-packages (from rasa_nlu[spacy]) (2.21.0)
# Requirement already satisfied: coloredlogs~=10.0 in /opt/conda/lib/python3.6/site-packages (from rasa_nlu[spacy]) (10.0)
# Requirement already satisfied: ruamel.yaml~=0.15.7 in /opt/conda/lib/python3.6/site-packages (from rasa_nlu[spacy]) (0.15.100)
# Requirement already satisfied: scikit-learn~=0.20.2 in /opt/conda/lib/python3.6/site-packages (from rasa_nlu[spacy]) (0.20.3)
# Requirement already satisfied: packaging~=18.0 in /opt/conda/lib/python3.6/site-packages (from rasa_nlu[spacy]) (18.0)
# Requirement already satisfied: matplotlib~=2.2 in /opt/conda/lib/python3.6/site-packages (from rasa_nlu[spacy]) (2.2.5)
# Requirement already satisfied: gevent~=1.3 in /opt/conda/lib/python3.6/site-packages (from rasa_nlu[spacy]) (1.3.0)
# Requirement already satisfied: future~=0.17.1 in /opt/conda/lib/python3.6/site-packages (from rasa_nlu[spacy]) (0.17.1)
# Requirement already satisfied: klein~=17.10 in /opt/conda/lib/python3.6/site-packages (from rasa_nlu[spacy]) (17.10.0)
# Requirement already satisfied: boto3~=1.9 in /opt/conda/lib/python3.6/site-packages (from rasa_nlu[spacy]) (1.9.130)
# Requirement already satisfied: cloudpickle~=0.6.1 in /opt/conda/lib/python3.6/site-packages (from rasa_nlu[spacy]) (0.6.1)
# Requirement already satisfied: numpy>=1.16 in /opt/conda/lib/python3.6/site-packages (from rasa_nlu[spacy]) (1.16.2)
# Requirement already satisfied: jsonschema~=2.6 in /opt/conda/lib/python3.6/site-packages (from rasa_nlu[spacy]) (2.6.0)
# Requirement already satisfied: tqdm~=4.19 in /opt/conda/lib/python3.6/site-packages (from rasa_nlu[spacy]) (4.31.1)
# Requirement already satisfied: simplejson~=3.13 in /opt/conda/lib/python3.6/site-packages (from rasa_nlu[spacy]) (3.17.2)
# Collecting sklearn-crfsuite~=0.3.6; extra == "spacy" (from rasa_nlu[spacy])
#   Downloading https://files.pythonhosted.org/packages/25/74/5b7befa513482e6dee1f3dd68171a6c9dfc14c0eaa00f885ffeba54fe9b0/sklearn_crfsuite-0.3.6-py2.py3-none-any.whl
# Collecting spacy<=2.0.18,>2.0; extra == "spacy" (from rasa_nlu[spacy])
#   Downloading https://files.pythonhosted.org/packages/ae/6e/a89da6b5c83f8811e46e3a9270c1aed90e9b9ee6c60faf52b7239e5d3d69/spacy-2.0.18-cp36-cp36m-manylinux1_x86_64.whl (25.2MB)
#     100% |████████████████████████████████| 25.2MB 1.8MB/s
# Requirement already satisfied: scipy~=1.2; extra == "spacy" in /opt/conda/lib/python3.6/site-packages (from rasa_nlu[spacy]) (1.5.2)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.6/site-packages (from requests~=2.20->rasa_nlu[spacy]) (2019.3.9)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /opt/conda/lib/python3.6/site-packages (from requests~=2.20->rasa_nlu[spacy]) (3.0.4)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in /opt/conda/lib/python3.6/site-packages (from requests~=2.20->rasa_nlu[spacy]) (1.22)
# Requirement already satisfied: idna<2.9,>=2.5 in /opt/conda/lib/python3.6/site-packages (from requests~=2.20->rasa_nlu[spacy]) (2.6)
# Requirement already satisfied: humanfriendly>=4.7 in /opt/conda/lib/python3.6/site-packages (from coloredlogs~=10.0->rasa_nlu[spacy]) (8.2)
# Requirement already satisfied: six in /opt/conda/lib/python3.6/site-packages (from packaging~=18.0->rasa_nlu[spacy]) (1.12.0)
# Requirement already satisfied: pyparsing>=2.0.2 in /opt/conda/lib/python3.6/site-packages (from packaging~=18.0->rasa_nlu[spacy]) (2.2.0)
# Requirement already satisfied: pytz in /opt/conda/lib/python3.6/site-packages (from matplotlib~=2.2->rasa_nlu[spacy]) (2018.9)
# Requirement already satisfied: python-dateutil>=2.1 in /opt/conda/lib/python3.6/site-packages (from matplotlib~=2.2->rasa_nlu[spacy]) (2.8.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/conda/lib/python3.6/site-packages (from matplotlib~=2.2->rasa_nlu[spacy]) (1.0.1)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.6/site-packages (from matplotlib~=2.2->rasa_nlu[spacy]) (0.10.0)
# Requirement already satisfied: greenlet>=0.4.13 in /opt/conda/lib/python3.6/site-packages (from gevent~=1.3->rasa_nlu[spacy]) (0.4.13)
# Requirement already satisfied: werkzeug in /opt/conda/lib/python3.6/site-packages (from klein~=17.10->rasa_nlu[spacy]) (0.14.1)
# Requirement already satisfied: Twisted>=15.5 in /opt/conda/lib/python3.6/site-packages (from klein~=17.10->rasa_nlu[spacy]) (20.3.0)
# Requirement already satisfied: incremental in /opt/conda/lib/python3.6/site-packages (from klein~=17.10->rasa_nlu[spacy]) (17.5.0)
# Requirement already satisfied: jmespath<1.0.0,>=0.7.1 in /opt/conda/lib/python3.6/site-packages (from boto3~=1.9->rasa_nlu[spacy]) (0.9.4)
# Requirement already satisfied: botocore<1.13.0,>=1.12.130 in /opt/conda/lib/python3.6/site-packages (from boto3~=1.9->rasa_nlu[spacy]) (1.12.130)
# Requirement already satisfied: s3transfer<0.3.0,>=0.2.0 in /opt/conda/lib/python3.6/site-packages (from boto3~=1.9->rasa_nlu[spacy]) (0.2.0)
# Collecting python-crfsuite>=0.8.3 (from sklearn-crfsuite~=0.3.6; extra == "spacy"->rasa_nlu[spacy])
#   Downloading https://files.pythonhosted.org/packages/95/99/869dde6dbf3e0d07a013c8eebfb0a3d30776334e0097f8432b631a9a3a19/python_crfsuite-0.9.7-cp36-cp36m-manylinux1_x86_64.whl (743kB)
#     100% |████████████████████████████████| 747kB 16.9MB/s
# Requirement already satisfied: tabulate in /opt/conda/lib/python3.6/site-packages/tabulate-0.8.3-py3.6.egg (from sklearn-crfsuite~=0.3.6; extra == "spacy"->rasa_nlu[spacy]) (0.8.3)
# Collecting ujson>=1.35 (from spacy<=2.0.18,>2.0; extra == "spacy"->rasa_nlu[spacy])
#   Downloading https://files.pythonhosted.org/packages/be/1a/36ead6ae1bc3b82ea864ef87f8c8e1e06bec3a745dc65915f47b46f241d0/ujson-3.1.0-cp36-cp36m-manylinux1_x86_64.whl (175kB)
#     100% |████████████████████████████████| 184kB 24.1MB/s
# Requirement already satisfied: dill<0.3,>=0.2 in /opt/conda/lib/python3.6/site-packages (from spacy<=2.0.18,>2.0; extra == "spacy"->rasa_nlu[spacy]) (0.2.9)
# Collecting regex==2018.01.10 (from spacy<=2.0.18,>2.0; extra == "spacy"->rasa_nlu[spacy])
#   Downloading https://files.pythonhosted.org/packages/76/f4/7146c3812f96fcaaf2d06ff6862582302626a59011ccb6f2833bb38d80f7/regex-2018.01.10.tar.gz (612kB)
#     100% |████████████████████████████████| 614kB 19.0MB/s
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /opt/conda/lib/python3.6/site-packages (from spacy<=2.0.18,>2.0; extra == "spacy"->rasa_nlu[spacy]) (1.0.0)
# Requirement already satisfied: plac<1.0.0,>=0.9.6 in /opt/conda/lib/python3.6/site-packages (from spacy<=2.0.18,>2.0; extra == "spacy"->rasa_nlu[spacy]) (0.9.6)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /opt/conda/lib/python3.6/site-packages (from spacy<=2.0.18,>2.0; extra == "spacy"->rasa_nlu[spacy]) (2.0.2)
# Collecting thinc<6.13.0,>=6.12.1 (from spacy<=2.0.18,>2.0; extra == "spacy"->rasa_nlu[spacy])
#   Downloading https://files.pythonhosted.org/packages/db/a7/46640a46fd707aeb204aa4257a70974b6a22a0204ba703164d803215776f/thinc-6.12.1-cp36-cp36m-manylinux1_x86_64.whl (1.9MB)
#     100% |████████████████████████████████| 1.9MB 12.2MB/s
# Requirement already satisfied: preshed<2.1.0,>=2.0.1 in /opt/conda/lib/python3.6/site-packages (from spacy<=2.0.18,>2.0; extra == "spacy"->rasa_nlu[spacy]) (2.0.1)
# Requirement already satisfied: setuptools in /opt/conda/lib/python3.6/site-packages (from kiwisolver>=1.0.1->matplotlib~=2.2->rasa_nlu[spacy]) (39.1.0)
# Requirement already satisfied: attrs>=19.2.0 in /opt/conda/lib/python3.6/site-packages (from Twisted>=15.5->klein~=17.10->rasa_nlu[spacy]) (20.2.0)
# Requirement already satisfied: PyHamcrest!=1.10.0,>=1.9.0 in /opt/conda/lib/python3.6/site-packages (from Twisted>=15.5->klein~=17.10->rasa_nlu[spacy]) (2.0.2)
# Requirement already satisfied: constantly>=15.1 in /opt/conda/lib/python3.6/site-packages (from Twisted>=15.5->klein~=17.10->rasa_nlu[spacy]) (15.1.0)
# Requirement already satisfied: zope.interface>=4.4.2 in /opt/conda/lib/python3.6/site-packages (from Twisted>=15.5->klein~=17.10->rasa_nlu[spacy]) (5.1.0)
# Requirement already satisfied: hyperlink>=17.1.1 in /opt/conda/lib/python3.6/site-packages (from Twisted>=15.5->klein~=17.10->rasa_nlu[spacy]) (20.0.1)
# Requirement already satisfied: Automat>=0.3.0 in /opt/conda/lib/python3.6/site-packages (from Twisted>=15.5->klein~=17.10->rasa_nlu[spacy]) (20.2.0)
# Requirement already satisfied: docutils>=0.10 in /opt/conda/lib/python3.6/site-packages (from botocore<1.13.0,>=1.12.130->boto3~=1.9->rasa_nlu[spacy]) (0.14)
# Collecting msgpack-numpy<0.4.4 (from thinc<6.13.0,>=6.12.1->spacy<=2.0.18,>2.0; extra == "spacy"->rasa_nlu[spacy])
#   Downloading https://files.pythonhosted.org/packages/ad/45/464be6da85b5ca893cfcbd5de3b31a6710f636ccb8521b17bd4110a08d94/msgpack_numpy-0.4.3.2-py2.py3-none-any.whl
# Requirement already satisfied: wrapt<1.11.0,>=1.10.0 in /opt/conda/lib/python3.6/site-packages (from thinc<6.13.0,>=6.12.1->spacy<=2.0.18,>2.0; extra == "spacy"->rasa_nlu[spacy]) (1.10.11)
# Requirement already satisfied: cytoolz<0.10,>=0.9.0 in /opt/conda/lib/python3.6/site-packages (from thinc<6.13.0,>=6.12.1->spacy<=2.0.18,>2.0; extra == "spacy"->rasa_nlu[spacy]) (0.9.0.1)
# Collecting msgpack<0.6.0,>=0.5.6 (from thinc<6.13.0,>=6.12.1->spacy<=2.0.18,>2.0; extra == "spacy"->rasa_nlu[spacy])
#   Downloading https://files.pythonhosted.org/packages/22/4e/dcf124fd97e5f5611123d6ad9f40ffd6eb979d1efdc1049e28a795672fcd/msgpack-0.5.6-cp36-cp36m-manylinux1_x86_64.whl (315kB)
#     100% |████████████████████████████████| 317kB 19.9MB/s
# Requirement already satisfied: toolz>=0.8.0 in /opt/conda/lib/python3.6/site-packages (from cytoolz<0.10,>=0.9.0->thinc<6.13.0,>=6.12.1->spacy<=2.0.18,>2.0; extra == "spacy"->rasa_nlu[spacy]) (0.9.0)
# Building wheels for collected packages: regex
# done
#   Stored in directory: /root/.cache/pip/wheels/74/17/3f/c77bba99efd74ba1a19862c9dd97f4b6d735e2826721dc00ff
# Successfully built regex
# tensorpack 0.9.4 has requirement msgpack-numpy>=0.4.4.2, but you'll have msgpack-numpy 0.4.3.2 which is incompatible.
# en-core-web-sm 2.1.0 has requirement spacy>=2.1.0, but you'll have spacy 2.0.18 which is incompatible.
# en-core-web-lg 2.1.0 has requirement spacy>=2.1.0, but you'll have spacy 2.0.18 which is incompatible.
# Installing collected packages: python-crfsuite, sklearn-crfsuite, ujson, regex, msgpack, msgpack-numpy, thinc, spacy
#   Found existing installation: regex 2019.3.12
#     Uninstalling regex-2019.3.12:
#       Successfully uninstalled regex-2019.3.12
#   Found existing installation: msgpack 0.6.1
#     Uninstalling msgpack-0.6.1:
#       Successfully uninstalled msgpack-0.6.1
#   Found existing installation: msgpack-numpy 0.4.4.2
#     Uninstalling msgpack-numpy-0.4.4.2:
#       Successfully uninstalled msgpack-numpy-0.4.4.2
#   Found existing installation: thinc 7.0.4
#     Uninstalling thinc-7.0.4:
#       Successfully uninstalled thinc-7.0.4
#   Found existing installation: spacy 2.1.3
#     Uninstalling spacy-2.1.3:
#       Successfully uninstalled spacy-2.1.3
# Successfully installed msgpack-0.5.6 msgpack-numpy-0.4.3.2 python-crfsuite-0.9.7 regex-2018.1.10 sklearn-crfsuite-0.3.6 spacy-2.0.18 thinc-6.12.1 ujson-3.1.0
# You are using pip version 19.0.3, however version 20.2.2 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.
# Collecting en_core_web_lg==2.0.0 from https://github.com/explosion/spacy-models/releases/download/en_core_web_lg-2.0.0/en_core_web_lg-2.0.0.tar.gz#egg=en_core_web_lg==2.0.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_lg-2.0.0/en_core_web_lg-2.0.0.tar.gz (852.3MB)
#     100% |████████████████████████████████| 852.3MB 9.5MB/s
# Installing collected packages: en-core-web-lg
#   Found existing installation: en-core-web-lg 2.1.0
#     Uninstalling en-core-web-lg-2.1.0:
#       Successfully uninstalled en-core-web-lg-2.1.0
# done
# Successfully installed en-core-web-lg-2.0.0
# You are using pip version 19.0.3, however version 20.2.2 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.
#
#     Linking successful
#     /opt/conda/lib/python3.6/site-packages/en_core_web_lg -->
#     /opt/conda/lib/python3.6/site-packages/spacy/data/en_core_web_lg
#
#     You can now load the model via spacy.load('en_core_web_lg')
#
#
#     Link 'en' already exists
#     To overwrite an existing link, use the --force flag.
#
# Collecting scikit-learn
#   Downloading https://files.pythonhosted.org/packages/5c/a1/273def87037a7fb010512bbc5901c31cfddfca8080bc63b42b26e3cc55b3/scikit_learn-0.23.2-cp36-cp36m-manylinux1_x86_64.whl (6.8MB)
#     100% |████████████████████████████████| 6.8MB 3.8MB/s
# Requirement already up-to-date: scipy in /opt/conda/lib/python3.6/site-packages (1.5.2)
# Requirement already up-to-date: sklearn-crfsuite in /opt/conda/lib/python3.6/site-packages (0.3.6)
# Requirement already satisfied, skipping upgrade: numpy>=1.13.3 in /opt/conda/lib/python3.6/site-packages (from scikit-learn) (1.16.2)
# Collecting threadpoolctl>=2.0.0 (from scikit-learn)
#   Downloading https://files.pythonhosted.org/packages/f7/12/ec3f2e203afa394a149911729357aa48affc59c20e2c1c8297a60f33f133/threadpoolctl-2.1.0-py3-none-any.whl
# Requirement already satisfied, skipping upgrade: joblib>=0.11 in /opt/conda/lib/python3.6/site-packages (from scikit-learn) (0.13.2)
# Requirement already satisfied, skipping upgrade: python-crfsuite>=0.8.3 in /opt/conda/lib/python3.6/site-packages (from sklearn-crfsuite) (0.9.7)
# Requirement already satisfied, skipping upgrade: six in /opt/conda/lib/python3.6/site-packages (from sklearn-crfsuite) (1.12.0)
# Requirement already satisfied, skipping upgrade: tqdm>=2.0 in /opt/conda/lib/python3.6/site-packages (from sklearn-crfsuite) (4.31.1)
# Requirement already satisfied, skipping upgrade: tabulate in /opt/conda/lib/python3.6/site-packages/tabulate-0.8.3-py3.6.egg (from sklearn-crfsuite) (0.8.3)
# rasa-nlu 0.15.1 has requirement scikit-learn~=0.20.2, but you'll have scikit-learn 0.23.2 which is incompatible.
# rasa-core 0.14.5 has requirement scikit-learn~=0.20.0, but you'll have scikit-learn 0.23.2 which is incompatible.
# lime 0.1.1.33 has requirement matplotlib==2.1.0, but you'll have matplotlib 2.2.5 which is incompatible.
# kmodes 0.10.0 has requirement scikit-learn<0.20.0,>=0.19.0, but you'll have scikit-learn 0.23.2 which is incompatible.
# kmeans-smote 0.1.2 has requirement imbalanced-learn<0.5,>=0.4.0, but you'll have imbalanced-learn 0.5.0.dev0 which is incompatible.
# kmeans-smote 0.1.2 has requirement numpy<1.16,>=1.13, but you'll have numpy 1.16.2 which is incompatible.
# kmeans-smote 0.1.2 has requirement scikit-learn<0.21,>=0.19.0, but you'll have scikit-learn 0.23.2 which is incompatible.
# Installing collected packages: threadpoolctl, scikit-learn
#   Found existing installation: scikit-learn 0.20.3
#     Uninstalling scikit-learn-0.20.3:
#       Successfully uninstalled scikit-learn-0.20.3
# Successfully installed scikit-learn-0.23.2 threadpoolctl-2.1.0
# You are using pip version 19.0.3, however version 20.2.2 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.
# Requirement already satisfied: rasa_nlu in /opt/conda/lib/python3.6/site-packages (0.15.1)
# Requirement already satisfied: jsonschema~=2.6 in /opt/conda/lib/python3.6/site-packages (from rasa_nlu) (2.6.0)
# Requirement already satisfied: numpy>=1.16 in /opt/conda/lib/python3.6/site-packages (from rasa_nlu) (1.16.2)
# Requirement already satisfied: typing~=3.6 in /opt/conda/lib/python3.6/site-packages (from rasa_nlu) (3.6.4)
# Requirement already satisfied: cloudpickle~=0.6.1 in /opt/conda/lib/python3.6/site-packages (from rasa_nlu) (0.6.1)
# Requirement already satisfied: klein~=17.10 in /opt/conda/lib/python3.6/site-packages (from rasa_nlu) (17.10.0)
# Requirement already satisfied: tqdm~=4.19 in /opt/conda/lib/python3.6/site-packages (from rasa_nlu) (4.31.1)
# Requirement already satisfied: requests~=2.20 in /opt/conda/lib/python3.6/site-packages (from rasa_nlu) (2.21.0)
# Requirement already satisfied: packaging~=18.0 in /opt/conda/lib/python3.6/site-packages (from rasa_nlu) (18.0)
# Requirement already satisfied: coloredlogs~=10.0 in /opt/conda/lib/python3.6/site-packages (from rasa_nlu) (10.0)
# Requirement already satisfied: future~=0.17.1 in /opt/conda/lib/python3.6/site-packages (from rasa_nlu) (0.17.1)
# Requirement already satisfied: simplejson~=3.13 in /opt/conda/lib/python3.6/site-packages (from rasa_nlu) (3.17.2)
# Requirement already satisfied: boto3~=1.9 in /opt/conda/lib/python3.6/site-packages (from rasa_nlu) (1.9.130)
# Requirement already satisfied: matplotlib~=2.2 in /opt/conda/lib/python3.6/site-packages (from rasa_nlu) (2.2.5)
# Requirement already satisfied: ruamel.yaml~=0.15.7 in /opt/conda/lib/python3.6/site-packages (from rasa_nlu) (0.15.100)
# Requirement already satisfied: gevent~=1.3 in /opt/conda/lib/python3.6/site-packages (from rasa_nlu) (1.3.0)
# Collecting scikit-learn~=0.20.2 (from rasa_nlu)
#   Downloading https://files.pythonhosted.org/packages/96/5b/5da31a6572dc6b7b2846a7cfcbe2e060a0e6af0e1059a6516965e40371b7/scikit_learn-0.20.4-cp36-cp36m-manylinux1_x86_64.whl (5.4MB)
#     100% |████████████████████████████████| 5.4MB 3.5MB/s
# Requirement already satisfied: incremental in /opt/conda/lib/python3.6/site-packages (from klein~=17.10->rasa_nlu) (17.5.0)
# Requirement already satisfied: six in /opt/conda/lib/python3.6/site-packages (from klein~=17.10->rasa_nlu) (1.12.0)
# Requirement already satisfied: Twisted>=15.5 in /opt/conda/lib/python3.6/site-packages (from klein~=17.10->rasa_nlu) (20.3.0)
# Requirement already satisfied: werkzeug in /opt/conda/lib/python3.6/site-packages (from klein~=17.10->rasa_nlu) (0.14.1)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /opt/conda/lib/python3.6/site-packages (from requests~=2.20->rasa_nlu) (3.0.4)
# Requirement already satisfied: idna<2.9,>=2.5 in /opt/conda/lib/python3.6/site-packages (from requests~=2.20->rasa_nlu) (2.6)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.6/site-packages (from requests~=2.20->rasa_nlu) (2019.3.9)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in /opt/conda/lib/python3.6/site-packages (from requests~=2.20->rasa_nlu) (1.22)
# Requirement already satisfied: pyparsing>=2.0.2 in /opt/conda/lib/python3.6/site-packages (from packaging~=18.0->rasa_nlu) (2.2.0)
# Requirement already satisfied: humanfriendly>=4.7 in /opt/conda/lib/python3.6/site-packages (from coloredlogs~=10.0->rasa_nlu) (8.2)
# Requirement already satisfied: s3transfer<0.3.0,>=0.2.0 in /opt/conda/lib/python3.6/site-packages (from boto3~=1.9->rasa_nlu) (0.2.0)
# Requirement already satisfied: botocore<1.13.0,>=1.12.130 in /opt/conda/lib/python3.6/site-packages (from boto3~=1.9->rasa_nlu) (1.12.130)
# Requirement already satisfied: jmespath<1.0.0,>=0.7.1 in /opt/conda/lib/python3.6/site-packages (from boto3~=1.9->rasa_nlu) (0.9.4)
# Requirement already satisfied: pytz in /opt/conda/lib/python3.6/site-packages (from matplotlib~=2.2->rasa_nlu) (2018.9)
# Requirement already satisfied: python-dateutil>=2.1 in /opt/conda/lib/python3.6/site-packages (from matplotlib~=2.2->rasa_nlu) (2.8.1)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.6/site-packages (from matplotlib~=2.2->rasa_nlu) (0.10.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/conda/lib/python3.6/site-packages (from matplotlib~=2.2->rasa_nlu) (1.0.1)
# Requirement already satisfied: greenlet>=0.4.13 in /opt/conda/lib/python3.6/site-packages (from gevent~=1.3->rasa_nlu) (0.4.13)
# Requirement already satisfied: scipy>=0.13.3 in /opt/conda/lib/python3.6/site-packages (from scikit-learn~=0.20.2->rasa_nlu) (1.5.2)
# Requirement already satisfied: hyperlink>=17.1.1 in /opt/conda/lib/python3.6/site-packages (from Twisted>=15.5->klein~=17.10->rasa_nlu) (20.0.1)
# Requirement already satisfied: Automat>=0.3.0 in /opt/conda/lib/python3.6/site-packages (from Twisted>=15.5->klein~=17.10->rasa_nlu) (20.2.0)
# Requirement already satisfied: PyHamcrest!=1.10.0,>=1.9.0 in /opt/conda/lib/python3.6/site-packages (from Twisted>=15.5->klein~=17.10->rasa_nlu) (2.0.2)
# Requirement already satisfied: zope.interface>=4.4.2 in /opt/conda/lib/python3.6/site-packages (from Twisted>=15.5->klein~=17.10->rasa_nlu) (5.1.0)
# Requirement already satisfied: attrs>=19.2.0 in /opt/conda/lib/python3.6/site-packages (from Twisted>=15.5->klein~=17.10->rasa_nlu) (20.2.0)
# Requirement already satisfied: constantly>=15.1 in /opt/conda/lib/python3.6/site-packages (from Twisted>=15.5->klein~=17.10->rasa_nlu) (15.1.0)
# Requirement already satisfied: docutils>=0.10 in /opt/conda/lib/python3.6/site-packages (from botocore<1.13.0,>=1.12.130->boto3~=1.9->rasa_nlu) (0.14)
# Requirement already satisfied: setuptools in /opt/conda/lib/python3.6/site-packages (from kiwisolver>=1.0.1->matplotlib~=2.2->rasa_nlu) (39.1.0)
# lime 0.1.1.33 has requirement matplotlib==2.1.0, but you'll have matplotlib 2.2.5 which is incompatible.
# kmodes 0.10.0 has requirement scikit-learn<0.20.0,>=0.19.0, but you'll have scikit-learn 0.20.4 which is incompatible.
# kmeans-smote 0.1.2 has requirement imbalanced-learn<0.5,>=0.4.0, but you'll have imbalanced-learn 0.5.0.dev0 which is incompatible.
# kmeans-smote 0.1.2 has requirement numpy<1.16,>=1.13, but you'll have numpy 1.16.2 which is incompatible.
# Installing collected packages: scikit-learn
#   Found existing installation: scikit-learn 0.23.2
#     Uninstalling scikit-learn-0.23.2:
#       Successfully uninstalled scikit-learn-0.23.2
# Successfully installed scikit-learn-0.20.4
# You are using pip version 19.0.3, however version 20.2.2 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.
# Requirement already satisfied: rasa_nlu[spacy] in /opt/conda/lib/python3.6/site-packages (0.15.1)
# Requirement already satisfied: numpy>=1.16 in /opt/conda/lib/python3.6/site-packages (from rasa_nlu[spacy]) (1.16.2)
# Requirement already satisfied: simplejson~=3.13 in /opt/conda/lib/python3.6/site-packages (from rasa_nlu[spacy]) (3.17.2)
# Requirement already satisfied: jsonschema~=2.6 in /opt/conda/lib/python3.6/site-packages (from rasa_nlu[spacy]) (2.6.0)
# Requirement already satisfied: ruamel.yaml~=0.15.7 in /opt/conda/lib/python3.6/site-packages (from rasa_nlu[spacy]) (0.15.100)
# Requirement already satisfied: requests~=2.20 in /opt/conda/lib/python3.6/site-packages (from rasa_nlu[spacy]) (2.21.0)
# Requirement already satisfied: boto3~=1.9 in /opt/conda/lib/python3.6/site-packages (from rasa_nlu[spacy]) (1.9.130)
# Requirement already satisfied: tqdm~=4.19 in /opt/conda/lib/python3.6/site-packages (from rasa_nlu[spacy]) (4.31.1)
# Requirement already satisfied: future~=0.17.1 in /opt/conda/lib/python3.6/site-packages (from rasa_nlu[spacy]) (0.17.1)
# Requirement already satisfied: gevent~=1.3 in /opt/conda/lib/python3.6/site-packages (from rasa_nlu[spacy]) (1.3.0)
# Requirement already satisfied: scikit-learn~=0.20.2 in /opt/conda/lib/python3.6/site-packages (from rasa_nlu[spacy]) (0.20.4)
# Requirement already satisfied: klein~=17.10 in /opt/conda/lib/python3.6/site-packages (from rasa_nlu[spacy]) (17.10.0)
# Requirement already satisfied: packaging~=18.0 in /opt/conda/lib/python3.6/site-packages (from rasa_nlu[spacy]) (18.0)
# Requirement already satisfied: typing~=3.6 in /opt/conda/lib/python3.6/site-packages (from rasa_nlu[spacy]) (3.6.4)
# Requirement already satisfied: coloredlogs~=10.0 in /opt/conda/lib/python3.6/site-packages (from rasa_nlu[spacy]) (10.0)
# Requirement already satisfied: matplotlib~=2.2 in /opt/conda/lib/python3.6/site-packages (from rasa_nlu[spacy]) (2.2.5)
# Requirement already satisfied: cloudpickle~=0.6.1 in /opt/conda/lib/python3.6/site-packages (from rasa_nlu[spacy]) (0.6.1)
# Requirement already satisfied: sklearn-crfsuite~=0.3.6; extra == "spacy" in /opt/conda/lib/python3.6/site-packages (from rasa_nlu[spacy]) (0.3.6)
# Requirement already satisfied: spacy<=2.0.18,>2.0; extra == "spacy" in /opt/conda/lib/python3.6/site-packages (from rasa_nlu[spacy]) (2.0.18)
# Requirement already satisfied: scipy~=1.2; extra == "spacy" in /opt/conda/lib/python3.6/site-packages (from rasa_nlu[spacy]) (1.5.2)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.6/site-packages (from requests~=2.20->rasa_nlu[spacy]) (2019.3.9)
# Requirement already satisfied: idna<2.9,>=2.5 in /opt/conda/lib/python3.6/site-packages (from requests~=2.20->rasa_nlu[spacy]) (2.6)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in /opt/conda/lib/python3.6/site-packages (from requests~=2.20->rasa_nlu[spacy]) (1.22)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /opt/conda/lib/python3.6/site-packages (from requests~=2.20->rasa_nlu[spacy]) (3.0.4)
# Requirement already satisfied: botocore<1.13.0,>=1.12.130 in /opt/conda/lib/python3.6/site-packages (from boto3~=1.9->rasa_nlu[spacy]) (1.12.130)
# Requirement already satisfied: jmespath<1.0.0,>=0.7.1 in /opt/conda/lib/python3.6/site-packages (from boto3~=1.9->rasa_nlu[spacy]) (0.9.4)
# Requirement already satisfied: s3transfer<0.3.0,>=0.2.0 in /opt/conda/lib/python3.6/site-packages (from boto3~=1.9->rasa_nlu[spacy]) (0.2.0)
# Requirement already satisfied: greenlet>=0.4.13 in /opt/conda/lib/python3.6/site-packages (from gevent~=1.3->rasa_nlu[spacy]) (0.4.13)
# Requirement already satisfied: Twisted>=15.5 in /opt/conda/lib/python3.6/site-packages (from klein~=17.10->rasa_nlu[spacy]) (20.3.0)
# Requirement already satisfied: six in /opt/conda/lib/python3.6/site-packages (from klein~=17.10->rasa_nlu[spacy]) (1.12.0)
# Requirement already satisfied: werkzeug in /opt/conda/lib/python3.6/site-packages (from klein~=17.10->rasa_nlu[spacy]) (0.14.1)
# Requirement already satisfied: incremental in /opt/conda/lib/python3.6/site-packages (from klein~=17.10->rasa_nlu[spacy]) (17.5.0)
# Requirement already satisfied: pyparsing>=2.0.2 in /opt/conda/lib/python3.6/site-packages (from packaging~=18.0->rasa_nlu[spacy]) (2.2.0)
# Requirement already satisfied: humanfriendly>=4.7 in /opt/conda/lib/python3.6/site-packages (from coloredlogs~=10.0->rasa_nlu[spacy]) (8.2)
# Requirement already satisfied: pytz in /opt/conda/lib/python3.6/site-packages (from matplotlib~=2.2->rasa_nlu[spacy]) (2018.9)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/conda/lib/python3.6/site-packages (from matplotlib~=2.2->rasa_nlu[spacy]) (1.0.1)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.6/site-packages (from matplotlib~=2.2->rasa_nlu[spacy]) (0.10.0)
# Requirement already satisfied: python-dateutil>=2.1 in /opt/conda/lib/python3.6/site-packages (from matplotlib~=2.2->rasa_nlu[spacy]) (2.8.1)
# Requirement already satisfied: tabulate in /opt/conda/lib/python3.6/site-packages/tabulate-0.8.3-py3.6.egg (from sklearn-crfsuite~=0.3.6; extra == "spacy"->rasa_nlu[spacy]) (0.8.3)
# Requirement already satisfied: python-crfsuite>=0.8.3 in /opt/conda/lib/python3.6/site-packages (from sklearn-crfsuite~=0.3.6; extra == "spacy"->rasa_nlu[spacy]) (0.9.7)
# Requirement already satisfied: ujson>=1.35 in /opt/conda/lib/python3.6/site-packages (from spacy<=2.0.18,>2.0; extra == "spacy"->rasa_nlu[spacy]) (3.1.0)
# Requirement already satisfied: plac<1.0.0,>=0.9.6 in /opt/conda/lib/python3.6/site-packages (from spacy<=2.0.18,>2.0; extra == "spacy"->rasa_nlu[spacy]) (0.9.6)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /opt/conda/lib/python3.6/site-packages (from spacy<=2.0.18,>2.0; extra == "spacy"->rasa_nlu[spacy]) (2.0.2)
# Requirement already satisfied: thinc<6.13.0,>=6.12.1 in /opt/conda/lib/python3.6/site-packages (from spacy<=2.0.18,>2.0; extra == "spacy"->rasa_nlu[spacy]) (6.12.1)
# Requirement already satisfied: dill<0.3,>=0.2 in /opt/conda/lib/python3.6/site-packages (from spacy<=2.0.18,>2.0; extra == "spacy"->rasa_nlu[spacy]) (0.2.9)
# Requirement already satisfied: regex==2018.01.10 in /opt/conda/lib/python3.6/site-packages (from spacy<=2.0.18,>2.0; extra == "spacy"->rasa_nlu[spacy]) (2018.1.10)
# Requirement already satisfied: preshed<2.1.0,>=2.0.1 in /opt/conda/lib/python3.6/site-packages (from spacy<=2.0.18,>2.0; extra == "spacy"->rasa_nlu[spacy]) (2.0.1)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /opt/conda/lib/python3.6/site-packages (from spacy<=2.0.18,>2.0; extra == "spacy"->rasa_nlu[spacy]) (1.0.0)
# Requirement already satisfied: docutils>=0.10 in /opt/conda/lib/python3.6/site-packages (from botocore<1.13.0,>=1.12.130->boto3~=1.9->rasa_nlu[spacy]) (0.14)
# Requirement already satisfied: Automat>=0.3.0 in /opt/conda/lib/python3.6/site-packages (from Twisted>=15.5->klein~=17.10->rasa_nlu[spacy]) (20.2.0)
# Requirement already satisfied: PyHamcrest!=1.10.0,>=1.9.0 in /opt/conda/lib/python3.6/site-packages (from Twisted>=15.5->klein~=17.10->rasa_nlu[spacy]) (2.0.2)
# Requirement already satisfied: constantly>=15.1 in /opt/conda/lib/python3.6/site-packages (from Twisted>=15.5->klein~=17.10->rasa_nlu[spacy]) (15.1.0)
# Requirement already satisfied: zope.interface>=4.4.2 in /opt/conda/lib/python3.6/site-packages (from Twisted>=15.5->klein~=17.10->rasa_nlu[spacy]) (5.1.0)
# Requirement already satisfied: attrs>=19.2.0 in /opt/conda/lib/python3.6/site-packages (from Twisted>=15.5->klein~=17.10->rasa_nlu[spacy]) (20.2.0)
# Requirement already satisfied: hyperlink>=17.1.1 in /opt/conda/lib/python3.6/site-packages (from Twisted>=15.5->klein~=17.10->rasa_nlu[spacy]) (20.0.1)
# Requirement already satisfied: setuptools in /opt/conda/lib/python3.6/site-packages (from kiwisolver>=1.0.1->matplotlib~=2.2->rasa_nlu[spacy]) (39.1.0)
# Requirement already satisfied: msgpack<0.6.0,>=0.5.6 in /opt/conda/lib/python3.6/site-packages (from thinc<6.13.0,>=6.12.1->spacy<=2.0.18,>2.0; extra == "spacy"->rasa_nlu[spacy]) (0.5.6)
# Requirement already satisfied: cytoolz<0.10,>=0.9.0 in /opt/conda/lib/python3.6/site-packages (from thinc<6.13.0,>=6.12.1->spacy<=2.0.18,>2.0; extra == "spacy"->rasa_nlu[spacy]) (0.9.0.1)
# Requirement already satisfied: msgpack-numpy<0.4.4 in /opt/conda/lib/python3.6/site-packages (from thinc<6.13.0,>=6.12.1->spacy<=2.0.18,>2.0; extra == "spacy"->rasa_nlu[spacy]) (0.4.3.2)
# Requirement already satisfied: wrapt<1.11.0,>=1.10.0 in /opt/conda/lib/python3.6/site-packages (from thinc<6.13.0,>=6.12.1->spacy<=2.0.18,>2.0; extra == "spacy"->rasa_nlu[spacy]) (1.10.11)
# Requirement already satisfied: toolz>=0.8.0 in /opt/conda/lib/python3.6/site-packages (from cytoolz<0.10,>=0.9.0->thinc<6.13.0,>=6.12.1->spacy<=2.0.18,>2.0; extra == "spacy"->rasa_nlu[spacy]) (0.9.0)
# You are using pip version 19.0.3, however version 20.2.2 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %% [markdown]
# # imports

# %%
import spacy
import yaml
from spacy import displacy
from collections import Counter
import en_core_web_sm
import pandas as pd
import nltk
from nltk.tokenize import word_tokenize
from nltk.tag import pos_tag

from rasa_nlu.training_data import load_data
from rasa_nlu.config import RasaNLUModelConfig
from rasa_nlu.model import Trainer
from rasa_nlu.model import Metadata, Interpreter
from rasa_nlu import config

from nltk.chunk import conlltags2tree, tree2conlltags
from pprint import pprint
from nltk.chunk import ne_chunk

from bs4 import BeautifulSoup
import requests
import re
import os
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # About the data
#
# -> A collection of reviews of cafes, restaurants in Dhaka City, Bangladesh.
#
# **Dhaka - the capital of Bangladesh. There are a lot of tourists, businessmen and normal people in it. Often these people want to satisfy their hunger by eating at resturants. So the question arises: Is it worth eating in restaurants in this city? The reviews left by the restaurant guests come to our aid.**
#
# **The database has almost 17,000 reviews. For each review, apart from its contents, the number of characters that has been determined, and whether the review is positive or negative was determined. A positive review is one where the rating was above 3 (on a scale of 1 to 5) or "positive" in words. Let's start!**
#
# please check this notebook for more details : [What to order in Dhaka? 🍔](https://www.kaggle.com/michau96/what-to-order-in-dhaka)

# %% [markdown]
# let's load the restaurant review,dhaka dataset

# %%
restaurantbd = pd.read_csv('../input/restaurant-reviews-in-dhaka-bangladesh/reviews.csv')
restaurantbd.head()
# Out:
#                                          Review Text     ...      Recommends
# 0  Friendly staff, good food and homely environme...     ...            True
# 1  Well...The Food was Good___Intrerior design is...     ...            True
# 2  The man who is foodie like me for him arabian ...     ...             NaN
# 3  ordered pizza and they were unable to serve th...     ...           False
# 4  This place is too much comfortable & food is d...     ...             NaN
#
# [5 rows x 3 columns]

# %%
restaurantbd['Review Text'][1]
# Out:
# 'Well...The Food was Good___Intrerior design is nice... Environment was soo quite Fakafaka😜 Background music was too good... I gives you 9/10😊'

# %%
ex = restaurantbd['Review Text'][1]

# %% [markdown]
# ### applying word tokenization and part-of-speech tagging to the sentence.

# %%
def preprocess(sent):
    sent = nltk.word_tokenize(sent)
    sent = nltk.pos_tag(sent)
    return sent

sent = preprocess(ex)
sent
# Out:
# [('Well', 'RB'),
#  ('...', ':'),
#  ('The', 'DT'),
#  ('Food', 'NNP'),
#  ('was', 'VBD'),
#  ('Good___Intrerior', 'NNP'),
#  ('design', 'NN'),
#  ('is', 'VBZ'),
#  ('nice', 'JJ'),
#  ('...', ':'),
#  ('Environment', 'NNP'),
#  ('was', 'VBD'),
#  ('soo', 'VBN'),
#  ('quite', 'RB'),
#  ('Fakafaka😜', 'NNP'),
#  ('Background', 'NNP'),
#  ('music', 'NN'),
#  ('was', 'VBD'),
#  ('too', 'RB'),
#  ('good', 'JJ'),
#  ('...', ':'),
#  ('I', 'PRP'),
#  ('gives', 'VBZ'),
#  ('you', 'PRP'),
#  ('9/10😊', 'CD')]

# %% [markdown]
# ### chunking

# %% [markdown]
# The basic technique we will use for entity detection is chunking, which segments and labels multi-token sequences as illustrated in (picture below). The smaller boxes show the word-level tokenization and part-of-speech tagging, while the large boxes show higher-level chunking. Each of these larger boxes is called a chunk. Like tokenization, which omits whitespace, chunking usually selects a subset of the tokens. Also like tokenization, the pieces produced by a chunker do not overlap in the source text.
#
# ![](http://www.nltk.org/images/chunk-segmentation.png)

# %% [markdown]
# https://stackoverflow.com/questions/39124492/nltk-regexpparser-chunk-phrase-by-matching-exactly-one-item

# %%
pattern = 'NP: {<DT>?<JJ>*<NN>}'
cp      = nltk.RegexpParser(pattern)
cs       = cp.parse(sent)

print(cs)
# Out:
# (S
#   Well/RB
#   .../:
#   The/DT
#   Food/NNP
#   was/VBD
#   Good___Intrerior/NNP
#   (NP design/NN)
#   is/VBZ
#   nice/JJ
#   .../:
#   Environment/NNP
#   was/VBD
#   soo/VBN
#   quite/RB
#   Fakafaka😜/NNP
#   Background/NNP
#   (NP music/NN)
#   was/VBD
#   too/RB
#   good/JJ
#   .../:
#   I/PRP
#   gives/VBZ
#   you/PRP
#   9/10😊/CD)

# %% [markdown]
# tree2conlltags(t) - Return a list of 3-tuples containing (word, tag, IOB-tag). Convert a tree to the CoNLL IOB tag format.

# %% [markdown]
# check this : https://stackoverflow.com/questions/40879520/nltk-convert-a-chunked-tree-into-a-list-iob-tagging

# %%
iob_tagged = tree2conlltags(cs)
pprint(iob_tagged)
# Out:
# [('Well', 'RB', 'O'),
#  ('...', ':', 'O'),
#  ('The', 'DT', 'O'),
#  ('Food', 'NNP', 'O'),
#  ('was', 'VBD', 'O'),
#  ('Good___Intrerior', 'NNP', 'O'),
#  ('design', 'NN', 'B-NP'),
#  ('is', 'VBZ', 'O'),
#  ('nice', 'JJ', 'O'),
#  ('...', ':', 'O'),
#  ('Environment', 'NNP', 'O'),
#  ('was', 'VBD', 'O'),
#  ('soo', 'VBN', 'O'),
#  ('quite', 'RB', 'O'),
#  ('Fakafaka😜', 'NNP', 'O'),
#  ('Background', 'NNP', 'O'),
#  ('music', 'NN', 'B-NP'),
#  ('was', 'VBD', 'O'),
#  ('too', 'RB', 'O'),
#  ('good', 'JJ', 'O'),
#  ('...', ':', 'O'),
#  ('I', 'PRP', 'O'),
#  ('gives', 'VBZ', 'O'),
#  ('you', 'PRP', 'O'),
#  ('9/10😊', 'CD', 'O')]

# %%
ne_tree = ne_chunk(pos_tag(word_tokenize(ex)))
print(ne_tree)
# Out:
# (S
#   Well/RB
#   .../:
#   The/DT
#   (ORGANIZATION Food/NNP)
#   was/VBD
#   (ORGANIZATION Good___Intrerior/NNP)
#   design/NN
#   is/VBZ
#   nice/JJ
#   .../:
#   Environment/NNP
#   was/VBD
#   soo/VBN
#   quite/RB
#   Fakafaka😜/NNP
#   Background/NNP
#   music/NN
#   was/VBD
#   too/RB
#   good/JJ
#   .../:
#   I/PRP
#   gives/VBZ
#   you/PRP
#   9/10😊/CD)

# %% [markdown]
# ### Entity

# %%
# !pip3 install spacy
# !python3 -m spacy download en_core_web_sm
# Out:
# Requirement already satisfied: spacy in /opt/conda/lib/python3.6/site-packages (2.0.18)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /opt/conda/lib/python3.6/site-packages (from spacy) (2.0.2)
# Requirement already satisfied: numpy>=1.15.0 in /opt/conda/lib/python3.6/site-packages (from spacy) (1.16.2)
# Requirement already satisfied: dill<0.3,>=0.2 in /opt/conda/lib/python3.6/site-packages (from spacy) (0.2.9)
# Requirement already satisfied: ujson>=1.35 in /opt/conda/lib/python3.6/site-packages (from spacy) (3.1.0)
# Requirement already satisfied: plac<1.0.0,>=0.9.6 in /opt/conda/lib/python3.6/site-packages (from spacy) (0.9.6)
# Requirement already satisfied: preshed<2.1.0,>=2.0.1 in /opt/conda/lib/python3.6/site-packages (from spacy) (2.0.1)
# Requirement already satisfied: regex==2018.01.10 in /opt/conda/lib/python3.6/site-packages (from spacy) (2018.1.10)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /opt/conda/lib/python3.6/site-packages (from spacy) (2.21.0)
# Requirement already satisfied: thinc<6.13.0,>=6.12.1 in /opt/conda/lib/python3.6/site-packages (from spacy) (6.12.1)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /opt/conda/lib/python3.6/site-packages (from spacy) (1.0.0)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in /opt/conda/lib/python3.6/site-packages (from requests<3.0.0,>=2.13.0->spacy) (1.22)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.6/site-packages (from requests<3.0.0,>=2.13.0->spacy) (2019.3.9)
# Requirement already satisfied: idna<2.9,>=2.5 in /opt/conda/lib/python3.6/site-packages (from requests<3.0.0,>=2.13.0->spacy) (2.6)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /opt/conda/lib/python3.6/site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.0.4)
# Requirement already satisfied: wrapt<1.11.0,>=1.10.0 in /opt/conda/lib/python3.6/site-packages (from thinc<6.13.0,>=6.12.1->spacy) (1.10.11)
# Requirement already satisfied: msgpack-numpy<0.4.4 in /opt/conda/lib/python3.6/site-packages (from thinc<6.13.0,>=6.12.1->spacy) (0.4.3.2)
# Requirement already satisfied: six<2.0.0,>=1.10.0 in /opt/conda/lib/python3.6/site-packages (from thinc<6.13.0,>=6.12.1->spacy) (1.12.0)
# Requirement already satisfied: msgpack<0.6.0,>=0.5.6 in /opt/conda/lib/python3.6/site-packages (from thinc<6.13.0,>=6.12.1->spacy) (0.5.6)
# Requirement already satisfied: tqdm<5.0.0,>=4.10.0 in /opt/conda/lib/python3.6/site-packages (from thinc<6.13.0,>=6.12.1->spacy) (4.31.1)
# Requirement already satisfied: cytoolz<0.10,>=0.9.0 in /opt/conda/lib/python3.6/site-packages (from thinc<6.13.0,>=6.12.1->spacy) (0.9.0.1)
# Requirement already satisfied: toolz>=0.8.0 in /opt/conda/lib/python3.6/site-packages (from cytoolz<0.10,>=0.9.0->thinc<6.13.0,>=6.12.1->spacy) (0.9.0)
# You are using pip version 19.0.3, however version 20.2.2 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.
# Collecting en_core_web_sm==2.0.0 from https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-2.0.0/en_core_web_sm-2.0.0.tar.gz#egg=en_core_web_sm==2.0.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-2.0.0/en_core_web_sm-2.0.0.tar.gz (37.4MB)
#     100% |████████████████████████████████| 37.4MB 73.1MB/s
# Installing collected packages: en-core-web-sm
#   Found existing installation: en-core-web-sm 2.1.0
#     Uninstalling en-core-web-sm-2.1.0:
#       Successfully uninstalled en-core-web-sm-2.1.0
# done
# Successfully installed en-core-web-sm-2.0.0
# You are using pip version 19.0.3, however version 20.2.2 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.
#
#     Linking successful
#     /opt/conda/lib/python3.6/site-packages/en_core_web_sm -->
#     /opt/conda/lib/python3.6/site-packages/spacy/data/en_core_web_sm
#
#     You can now load the model via spacy.load('en_core_web_sm')

# %%
nlp = en_core_web_sm.load()

# %% [markdown]
# ![](http://www.nltk.org/images/ie-architecture.png)
#
# *Simple Pipeline Architecture for an Information Extraction System. This system takes the raw text of a document as its input, and generates a list of (entity, relation, entity) tuples as its output. For example, given a document that indicates that the company Georgia-Pacific is located in Atlanta, it might generate the tuple ([ORG: 'Georgia-Pacific'] 'in' [LOC: 'Atlanta']).*

# %%
nlp = spacy.load('en')
docx = nlp(u"I am looking for an Italian Restaurant where I can eat")

for word in docx.ents: 
    print("1.value : ",word.text,"2.entity : ",word.label_,"3.start : ",word.start_char,"4.end : ",word.end_char)
# Out:
# 1.value :  Italian 2.entity :  NORP 3.start :  20 4.end :  27

# %%
for i in range(5):
    ex = restaurantbd['Review Text'][i]
    print(">>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>REVIEW<<<<<<<<<<<<<<<<<<<<<<<<<<<")
    print(ex)
    doc = nlp(ex)
    print("************************OUTPUT*********************************")
    pprint([(X.text, X.label_) for X in doc.ents])
# Out:
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>REVIEW<<<<<<<<<<<<<<<<<<<<<<<<<<<
# Friendly staff, good food and homely environment 💜💜💜
# ************************OUTPUT*********************************
# [('💜💜💜', 'PERSON')]
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>REVIEW<<<<<<<<<<<<<<<<<<<<<<<<<<<
# Well...The Food was Good___Intrerior design is nice... Environment was soo quite Fakafaka😜 Background music was too good... I gives you 9/10😊
# ************************OUTPUT*********************************
# []
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>REVIEW<<<<<<<<<<<<<<<<<<<<<<<<<<<
# The man who is foodie like me for him arabian master is a nice place. Environment and food quality is too good. Specially their staffs’ behaviour are so nice. Good environment, quality food and and suitable price with these arabian master is awesome in a word.
# ************************OUTPUT*********************************
# []
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>REVIEW<<<<<<<<<<<<<<<<<<<<<<<<<<<
# ordered pizza and they were unable to serve then ordered set menu and then they took more than one hour to serve that setmenu.. and food quatity was so poor. please develop these quAlities.customers will surely come to enjoy. but my and my friends experience is so pathetic.as I proposed them to go there so it was my concern.so pathetic. 😑
# ************************OUTPUT*********************************
# [('more than one hour', 'TIME')]
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>REVIEW<<<<<<<<<<<<<<<<<<<<<<<<<<<
# This place is too much comfortable & food is delicious.. Every Item Is testy & pizza or set menu is Best... & most important Thing is Their behavior is friendly..It is very good place..environment is good enough.. behavior of all the staff is good and prices are reasonable.. Over all I liked their service system, Their behavior, Their place Everything..
# ************************OUTPUT*********************************
# []

# %%
doc = nlp(ex)
pprint([(X.text, X.label_) for X in doc.ents])
# Out:
# []

# %% [markdown]
# ### Token

# %% [markdown]
# <ul>
#     <li>B ==> the token begins an entity</li>
#     <li>I ==> the token is inside an entity</li>
#     <li>O ==> the token is outside an entity</li>
#     <li>' ' ==> no entity tag is set</li>
# </ul>

# %% [markdown]
# you can see we have got "[]" several times,why?
# the answer is here : https://medium.com/@rajat.jain1/natural-language-extraction-using-spacy-on-a-set-of-novels-88b159d68686
#
# Here is a summary of spaCy’s entity types.
#
# ![](https://miro.medium.com/max/767/0*SqZbOvfNIdPsuVh3.png)

# %%
pprint([(X, X.ent_iob_, X.ent_type_) for X in doc])
# Out:
# [(This, 'O', ''),
#  (place, 'O', ''),
#  (is, 'O', ''),
#  (too, 'O', ''),
#  (much, 'O', ''),
#  (comfortable, 'O', ''),
#  (&, 'O', ''),
#  (food, 'O', ''),
#  (is, 'O', ''),
#  (delicious, 'O', ''),
#  (.., 'O', ''),
#  (Every, 'O', ''),
#  (Item, 'O', ''),
#  (Is, 'O', ''),
#  (testy, 'O', ''),
#  (&, 'O', ''),
#  (pizza, 'O', ''),
#  (or, 'O', ''),
#  (set, 'O', ''),
#  (menu, 'O', ''),
#  (is, 'O', ''),
#  (Best, 'O', ''),
#  (..., 'O', ''),
#  (&, 'O', ''),
#  (most, 'O', ''),
#  (important, 'O', ''),
#  (Thing, 'O', ''),
#  (is, 'O', ''),
#  (Their, 'O', ''),
#  (behavior, 'O', ''),
#  (is, 'O', ''),
#  (friendly, 'O', ''),
#  (.., 'O', ''),
#  (It, 'O', ''),
#  (is, 'O', ''),
#  (very, 'O', ''),
#  (good, 'O', ''),
#  (place, 'O', ''),
#  (.., 'O', ''),
#  (environment, 'O', ''),
#  (is, 'O', ''),
#  (good, 'O', ''),
#  (enough, 'O', ''),
#  (.., 'O', ''),
#  (behavior, 'O', ''),
#  (of, 'O', ''),
#  (all, 'O', ''),
#  (the, 'O', ''),
#  (staff, 'O', ''),
#  (is, 'O', ''),
#  (good, 'O', ''),
#  (and, 'O', ''),
#  (prices, 'O', ''),
#  (are, 'O', ''),
#  (reasonable, 'O', ''),
#  (.., 'O', ''),
#  (Over, 'O', ''),
#  (all, 'O', ''),
#  (I, 'O', ''),
#  (liked, 'O', ''),
#  (their, 'O', ''),
#  (service, 'O', ''),
#  (system, 'O', ''),
#  (,, 'O', ''),
#  (Their, 'O', ''),
#  (behavior, 'O', ''),
#  (,, 'O', ''),
#  (Their, 'O', ''),
#  (place, 'O', ''),
#  (Everything, 'O', ''),
#  (.., 'O', '')]

# %%
nlp0 = spacy.load('en_core_web_sm')
nlp0.pipe_names
# Out:
# ['tagger', 'parser', 'ner']

# %% [markdown]
# # Using Rasa NLU and SpaCy

# %% [markdown]
# ![](https://cdn-images-1.medium.com/max/1000/1*Uf_qQ0zF8G8y9zUhndA08w.png)

# %% [markdown]
# we have 2 datasets,
#
# >>>Datasets<<<
#
# 1. demo-rasa.json
# 2. config_spacy.yaml

# %% [markdown]
# let's explore them

# %% [markdown]
# inside rasa_data.json we have :

# %%
# !cat ../input/rasaspacydata/rasa_data.json
# Out:
#   }

# %% [markdown]
# during interactive mode it shows correct output but after kernel commit i get blank black (empty) output,probably some  docker issue in kaggle,so i am pasting interactive mode's output as markdown below :

# %% [markdown]
# {
#     "rasa_nlu_data": {
#       "regex_features": [
#         {
#           "name": "zipcode",
#           "pattern": "[0-9]{5}"
#         },
#         {
#           "name": "greet",
#           "pattern": "hey[^\\s]*"
#         }
#       ],
#       "entity_synonyms": [
#         {
#           "value": "chinese",
#           "synonyms": ["Chinese", "Chines", "chines"]
#         },
#         {
#           "value": "vegetarian",
#           "synonyms": ["veggie", "vegg"]
#         }
#       ],
#       "common_examples": [
#         {
#           "text": "hey",
#           "intent": "greet",
#           "entities": []
#         },
#         {
#           "text": "howdy",
#           "intent": "greet",
#           "entities": []
#         },
#         {
#           "text": "hey there",
#           "intent": "greet",
#           "entities": []
#         },
#         {
#           "text": "hello",
#           "intent": "greet",
#           "entities": []
#         },
#         {
#           "text": "hi",
#           "intent": "greet",
#           "entities": []
#         },
#         {
#           "text": "good morning",
#           "intent": "greet",
#           "entities": []
#         },
#         {
#           "text": "good evening",
#           "intent": "greet",
#           "entities": []
#         },
#         {
#           "text": "dear sir",
#           "intent": "greet",
#           "entities": []
#         },
#         {
#           "text": "yes",
#           "intent": "affirm",
#           "entities": []
#         },
#         {
#           "text": "yep",
#           "intent": "affirm",
#           "entities": []
#         },
#         {
#           "text": "yeah",
#           "intent": "affirm",
#           "entities": []
#         },
#         {
#           "text": "indeed",
#           "intent": "affirm",
#           "entities": []
#         },
#         {
#           "text": "that's right",
#           "intent": "affirm",
#           "entities": []
#         },
#         {
#           "text": "ok",
#           "intent": "affirm",
#           "entities": []
#         },
#         {
#           "text": "great",
#           "intent": "affirm",
#           "entities": []
#         },
#         {
#           "text": "right, thank you",
#           "intent": "affirm",
#           "entities": []
#         },
#         {
#           "text": "correct",
#           "intent": "affirm",
#           "entities": []
#         },
#         {
#           "text": "great choice",
#           "intent": "affirm",
#           "entities": []
#         },
#         {
#           "text": "sounds really good",
#           "intent": "affirm",
#           "entities": []
#         },
#         {
#           "text": "i'm looking for a place to eat",
#           "intent": "restaurant_search",
#           "entities": []
#         },
#         {
#           "text": "I want to grab lunch",
#           "intent": "restaurant_search",
#           "entities": []
#         },
#         {
#           "text": "I am searching for a dinner spot",
#           "intent": "restaurant_search",
#           "entities": []
#         },
#         {
#           "text": "i'm looking for a place in the north of town",
#           "intent": "restaurant_search",
#           "entities": [
#             {
#               "start": 31,
#               "end": 36,
#               "value": "north",
#               "entity": "location"
#             }
#           ]
#         },
#         {
#           "text": "show me chinese restaurants",
#           "intent": "restaurant_search",
#           "entities": [
#             {
#               "start": 8,
#               "end": 15,
#               "value": "chinese",
#               "entity": "cuisine"
#             }
#           ]
#         },
#         {
#           "text": "show me chines restaurants in the north",
#           "intent": "restaurant_search",
#           "entities": [
#             {
#               "start": 8,
#               "end": 14,
#               "value": "chinese",
#               "entity": "cuisine"
#             },
#             {
#               "start": 34,
#               "end": 39,
#               "value": "north",
#               "entity": "location"
#             }
#           ]
#         },
#         {
#           "text": "show me a mexican place in the centre",
#           "intent": "restaurant_search",
#           "entities": [
#             {
#               "start": 31,
#               "end": 37,
#               "value": "centre",
#               "entity": "location"
#             },
#             {
#               "start": 10,
#               "end": 17,
#               "value": "mexican",
#               "entity": "cuisine"
#             }
#           ]
#         },
#         {
#           "text": "i am looking for an indian spot called olaolaolaolaolaola",
#           "intent": "restaurant_search",
#           "entities": [
#             {
#               "start": 20,
#               "end": 26,
#               "value": "indian",
#               "entity": "cuisine"
#             }
#           ]
#         },     {
#           "text": "search for restaurants",
#           "intent": "restaurant_search",
#           "entities": []
#         },
#         {
#           "text": "anywhere in the west",
#           "intent": "restaurant_search",
#           "entities": [
#             {
#               "start": 16,
#               "end": 20,
#               "value": "west",
#               "entity": "location"
#             }
#           ]
#         },
#         {
#           "text": "anywhere near 18328",
#           "intent": "restaurant_search",
#           "entities": [
#             {
#               "start": 14,
#               "end": 19,
#               "value": "18328",
#               "entity": "location"
#             }
#           ]
#         },
#         {
#           "text": "I am looking for asian fusion food",
#           "intent": "restaurant_search",
#           "entities": [
#             {
#               "start": 17,
#               "end": 29,
#               "value": "asian fusion",
#               "entity": "cuisine"
#             }
#           ]
#         },
#         {
#           "text": "I am looking a restaurant in 29432",
#           "intent": "restaurant_search",
#           "entities": [
#             {
#               "start": 29,
#               "end": 34,
#               "value": "29432",
#               "entity": "location"
#             }
#           ]
#         },
#         {
#           "text": "I am looking for mexican indian fusion",
#           "intent": "restaurant_search",
#           "entities": [
#             {
#               "start": 17,
#               "end": 38,
#               "value": "mexican indian fusion",
#               "entity": "cuisine"
#             }
#           ]
#         },
#         {
#           "text": "central indian restaurant",
#           "intent": "restaurant_search",
#           "entities": [
#             {
#               "start": 0,
#               "end": 7,
#               "value": "central",
#               "entity": "location"
#             },
#             {
#               "start": 8,
#               "end": 14,
#               "value": "indian",
#               "entity": "cuisine"
#             }
#           ]
#         },
#         {
#           "text": "bye",
#           "intent": "goodbye",
#           "entities": []
#         },
#         {
#           "text": "goodbye",
#           "intent": "goodbye",
#           "entities": []
#         },
#         {
#           "text": "good bye",
#           "intent": "goodbye",
#           "entities": []
#         },
#         {
#           "text": "stop",
#           "intent": "goodbye",
#           "entities": []
#         },
#         {
#           "text": "end",
#           "intent": "goodbye",
#           "entities": []
#         },
#         {
#           "text": "farewell",
#           "intent": "goodbye",
#           "entities": []
#         },
#         {
#           "text": "Bye bye",
#           "intent": "goodbye",
#           "entities": []
#         },
#         {
#           "text": "have a good one",
#           "intent": "goodbye",
#           "entities": []
#         }
#       ]
#     }
#   }

# %% [markdown]
# let's load rasa_data.json data

# %%
train = load_data("../input/rasaspacydata/rasa_data.json")
train

# %%
Trainer.train?

# %%
#mytrainer = Trainer.train(config.load("../input/rasaspacydata/config_spacy.yaml"))

# %% [markdown]
# let's read config_spacy.yaml file

# %%
with open("../input/rasaspacydata/config_spacy.yaml", 'r') as stream:
    try:
        print(yaml.safe_load(stream))
    except yaml.YAMLError as exc:
        print(exc)
# Out:
# {'language': 'en', 'pipeline': 'spacy_sklearn'}

# %%
training_data = load_data('../input/rasaspacydata/rasa_data.json')
trainer = Trainer(config.load('../input/rasaspacydata/config_spacy.yaml')) 
trainer.train(training_data)
model_directory = trainer.persist('./models/')  # Returns the directory the model is stored in
# Out:
# Fitting 2 folds for each of 6 candidates, totalling 12 fits
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done  12 out of  12 | elapsed:    0.1s finished

# %%
# where `model_directory points to the folder the model is persisted in
interpreter = Interpreter.load(model_directory)

# %% [markdown]
# **Testing on simple sentence!**

# %%
# Prediction of Intent
interpreter.parse(u"I am looking for an Italian Restaurant where I can eat")
# Out:
# {'intent': {'name': 'restaurant_search', 'confidence': 0.6954585646004395},
#  'entities': [],
#  'intent_ranking': [{'name': 'restaurant_search',
#    'confidence': 0.6954585646004395},
#   {'name': 'affirm', 'confidence': 0.1866532286261028},
#   {'name': 'greet', 'confidence': 0.06439299878643577},
#   {'name': 'goodbye', 'confidence': 0.053495207987021565}],
#  'text': 'I am looking for an Italian Restaurant where I can eat'}

# %%
class bcolors:
    HEADER = '\033[95m'
    OKBLUE = '\033[94m'
    OKGREEN = '\033[92m'
    WARNING = '\033[93m'
    FAIL = '\033[91m'
    ENDC = '\033[0m'
    BOLD = '\033[1m'
    UNDERLINE = '\033[4m'

# %% [markdown]
# Testing on [**Restaurant Reviews in Dhaka, Bangladesh**](https://www.kaggle.com/tuxboy/restaurant-reviews-in-dhaka-bangladesh) dataset

# %%
for i in range(10):
    ex = restaurantbd['Review Text'][i]
    ex = interpreter.parse(ex)
    print(bcolors.OKBLUE + "---------------------------------------------------------------------------------------" + bcolors.OKBLUE)
    print(ex)
# Out:
# ---------------------------------------------------------------------------------------
# {'intent': {'name': 'restaurant_search', 'confidence': 0.5466333279849948}, 'entities': [], 'intent_ranking': [{'name': 'restaurant_search', 'confidence': 0.5466333279849948}, {'name': 'affirm', 'confidence': 0.20967939386792822}, {'name': 'greet', 'confidence': 0.13802598776133976}, {'name': 'goodbye', 'confidence': 0.10566129038573698}], 'text': 'Friendly staff, good food and homely environment 💜💜💜'}
# ---------------------------------------------------------------------------------------
# {'intent': {'name': 'restaurant_search', 'confidence': 0.5194643704668908}, 'entities': [], 'intent_ranking': [{'name': 'restaurant_search', 'confidence': 0.5194643704668908}, {'name': 'affirm', 'confidence': 0.2723965342149333}, {'name': 'greet', 'confidence': 0.11076155351774332}, {'name': 'goodbye', 'confidence': 0.09737754180043252}], 'text': 'Well...The Food was Good___Intrerior design is nice... Environment was soo quite Fakafaka😜 Background music was too good... I gives you 9/10😊'}
# ---------------------------------------------------------------------------------------
# {'intent': {'name': 'restaurant_search', 'confidence': 0.4920667369848275}, 'entities': [], 'intent_ranking': [{'name': 'restaurant_search', 'confidence': 0.4920667369848275}, {'name': 'affirm', 'confidence': 0.31063759793312085}, {'name': 'greet', 'confidence': 0.11119542182924809}, {'name': 'goodbye', 'confidence': 0.0861002432528036}], 'text': 'The man who is foodie like me for him arabian master is a nice place. Environment and food quality is too good. Specially their staffs’ behaviour are so nice. Good environment, quality food and and suitable price with these arabian master is awesome in a word.'}
# ---------------------------------------------------------------------------------------
# {'intent': {'name': 'restaurant_search', 'confidence': 0.5017774553412042}, 'entities': [], 'intent_ranking': [{'name': 'restaurant_search', 'confidence': 0.5017774553412042}, {'name': 'affirm', 'confidence': 0.29363831247901584}, {'name': 'greet', 'confidence': 0.11540766863609124}, {'name': 'goodbye', 'confidence': 0.0891765635436885}], 'text': 'ordered pizza and they were unable to serve then ordered set menu and then they took more than one hour to serve that setmenu.. and food quatity was so poor. please develop these quAlities.customers will surely come to enjoy. but my and my friends experience is so pathetic.as I proposed them to go there so it was my concern.so pathetic. 😑'}
# ---------------------------------------------------------------------------------------
# {'intent': {'name': 'restaurant_search', 'confidence': 0.48140940047066105}, 'entities': [], 'intent_ranking': [{'name': 'restaurant_search', 'confidence': 0.48140940047066105}, {'name': 'affirm', 'confidence': 0.32189377917097195}, {'name': 'greet', 'confidence': 0.10659877614931153}, {'name': 'goodbye', 'confidence': 0.09009804420905584}], 'text': 'This place is too much comfortable & food is delicious.. Every Item Is testy & pizza or set menu is Best... & most important Thing is Their behavior is friendly..It is very good place..environment is good enough.. behavior of all the staff is good and prices are reasonable.. Over all I liked their service system, Their behavior, Their place Everything..'}
# ---------------------------------------------------------------------------------------
# {'intent': {'name': 'affirm', 'confidence': 0.3947708745456191}, 'entities': [], 'intent_ranking': [{'name': 'affirm', 'confidence': 0.3947708745456191}, {'name': 'restaurant_search', 'confidence': 0.319428643591033}, {'name': 'greet', 'confidence': 0.14431282028263603}, {'name': 'goodbye', 'confidence': 0.14148766158071194}], 'text': '#5star great and very welcoming atmosphere.. pizza was greatest best...'}
# ---------------------------------------------------------------------------------------
# {'intent': {'name': 'restaurant_search', 'confidence': 0.4197132161249669}, 'entities': [], 'intent_ranking': [{'name': 'restaurant_search', 'confidence': 0.4197132161249669}, {'name': 'affirm', 'confidence': 0.33257030294535667}, {'name': 'goodbye', 'confidence': 0.1308074032014522}, {'name': 'greet', 'confidence': 0.11690907772822459}], 'text': 'I check it out like a second home of mine...feel frequent and relaxed....well manner, frankly attitude and of course fresh food have been delivered.. go ahead with a lot of warm wishes and undoubtedly with good food ..'}
# ---------------------------------------------------------------------------------------
# {'intent': {'name': 'restaurant_search', 'confidence': 0.5359945453854414}, 'entities': [], 'intent_ranking': [{'name': 'restaurant_search', 'confidence': 0.5359945453854414}, {'name': 'affirm', 'confidence': 0.2906962752750077}, {'name': 'greet', 'confidence': 0.0973174356107754}, {'name': 'goodbye', 'confidence': 0.07599174372877518}], 'text': 'Arabian Masters interior decoration is unique.Its food is tasty & a little bit spicy..Their staffs are very friendly..😊'}
# ---------------------------------------------------------------------------------------
# {'intent': {'name': 'restaurant_search', 'confidence': 0.4579733019484897}, 'entities': [], 'intent_ranking': [{'name': 'restaurant_search', 'confidence': 0.4579733019484897}, {'name': 'affirm', 'confidence': 0.30855339325648745}, {'name': 'greet', 'confidence': 0.14717297230649648}, {'name': 'goodbye', 'confidence': 0.08630033248852628}], 'text': 'you guys are awesome & I just love your "offer pizza" #tasty #Reasonableprice'}
# ---------------------------------------------------------------------------------------
# {'intent': {'name': 'restaurant_search', 'confidence': 0.388875230902893}, 'entities': [], 'intent_ranking': [{'name': 'restaurant_search', 'confidence': 0.388875230902893}, {'name': 'affirm', 'confidence': 0.35179869413558573}, {'name': 'greet', 'confidence': 0.14131322993955991}, {'name': 'goodbye', 'confidence': 0.1180128450219608}], 'text': 'Well behave Food was testy'}

# %% [markdown]
# references :
# 1. https://github.com/RasaHQ/rasa/issues/2057
# 2. https://github.com/RasaHQ/rasa/issues/1066
# 3. https://legacy-docs.rasa.com/docs/nlu/0.9.2/python/
# 4. http://www.nltk.org/book_1ed/ch07.html

# %% [markdown]
# NOTE : this problem occurs in google colab [**How to resolve KeyError: 'PUNKTSIDE_FIN'**](https://stackoverflow.com/questions/60068824/how-to-resolve-keyerror-punktside-fin)
